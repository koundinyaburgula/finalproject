# %% [markdown]
# # Introduction
#
# ## Thanks for starter notebook [ZACH NUSSBAUM](https://www.kaggle.com/zachnussbaum/cryptopunks-exploratory-data-analysis)
#
# ## Here is my [blog](https://baotramduong.medium.com/generate-nft-cryptopunks-with-deep-convolutional-generative-adversarial-network-dcgan-db35f0a1adb4)

# %% [markdown]
# An [NFT](https://en.wikipedia.org/wiki/Non-fungible_token) is a Non Fungible Token, unique tokens that can be traded and exchanged on the [Ethereum blockchain](https://en.wikipedia.org/wiki/Ethereum).
#
# [CryptoPunks](https://www.larvalabs.com/cryptopunks) is a collection of 10,000 unique collectible characters, each is a 24x24 pixel, 8-bit-style unique avatar, with proof of ownership stored on the Ethereum blockchain. Their creation began as an experiment, conducted by software developers Matt Hall and John Watkinson in 2017. The Cryptopunks were the inspiration for the [ERC-721](https://eips.ethereum.org/EIPS/eip-721) standard that powers most digital art and collectibles today.
#
# CryptoPunks is the very first NFT series to catch popular interest and one of the most actively traded today. As of October 2021, the market capitalization of all 10,000 CryptoPunks is estimated at around 1,600,00 ETH, or over 5B USD.
#
# In this project, we will use DCGAN (Deep Convolutional Generative Adversarial Network) and train it on the CryptoPunks dataset to generate new punks. GAN belongs to a group of [unsupervised learning](https://www.ibm.com/cloud/learn/unsupervised-learning#:~:text=Unsupervised%20learning,%20also%20known%20as,the%20need%20for%20human%20intervention) technique called [Generative Models](https://en.wikipedia.org/wiki/Generative_model). Generative Models are a type of machine learning models that are used to describe phenomena in data and enables computers to understand the real world. Generative Models and GANs have been ones of the most successful developments in the recent years in Computer Vision.

# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import os
import random
from tqdm import tqdm
import cv2 as cv
import PIL
from PIL import Image
# !pip install plotly
import plotly.express as px
from IPython import display

import tensorflow as tf
from tensorflow import keras

import torch
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
# !git clone https://github.com/cyatreya/kounya.git
# Out:
# Cloning into 'kounya'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
# !unzip /content/kounya/archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: imgs/imgs/550.png
#   inflating: imgs/imgs/5500.png
#   inflating: imgs/imgs/5501.png
#   inflating: imgs/imgs/5502.png
#   inflating: imgs/imgs/5503.png
#   inflating: imgs/imgs/5504.png
#   inflating: imgs/imgs/5505.png
#   inflating: imgs/imgs/5506.png
#   inflating: imgs/imgs/5507.png
#   inflating: imgs/imgs/5508.png
#   inflating: imgs/imgs/5509.png
#   inflating: imgs/imgs/551.png
#   inflating: imgs/imgs/5510.png
#   inflating: imgs/imgs/5511.png
#   inflating: imgs/imgs/5512.png
#   inflating: imgs/imgs/5513.png
#   inflating: imgs/imgs/5514.png
#   inflating: imgs/imgs/5515.png
#   inflating: imgs/imgs/5516.png
#   inflating: imgs/imgs/5517.png
#   inflating: imgs/imgs/5518.png
#   inflating: imgs/imgs/5519.png
#   inflating: imgs/imgs/552.png
#   inflating: imgs/imgs/5520.png
#   inflating: imgs/imgs/5521.png
#   inflating: imgs/imgs/5522.png
#   inflating: imgs/imgs/5523.png
#   inflating: imgs/imgs/5524.png
#   inflating: imgs/imgs/5525.png
#   inflating: imgs/imgs/5526.png
#   inflating: imgs/imgs/5527.png
#   inflating: imgs/imgs/5528.png
#   inflating: imgs/imgs/5529.png
#   inflating: imgs/imgs/553.png
#   inflating: imgs/imgs/5530.png
#   inflating: imgs/imgs/5531.png
#   inflating: imgs/imgs/5532.png
#   inflating: imgs/imgs/5533.png
#   inflating: imgs/imgs/5534.png
#   inflating: imgs/imgs/5535.png
#   inflating: imgs/imgs/5536.png
#   inflating: imgs/imgs/5537.png
#   inflating: imgs/imgs/5538.png
#   inflating: imgs/imgs/5539.png
#   inflating: imgs/imgs/554.png
#   inflating: imgs/imgs/5540.png
#   inflating: imgs/imgs/5541.png
#   inflating: imgs/imgs/5542.png
#   inflating: imgs/imgs/5543.png
#   inflating: imgs/imgs/5544.png
#   inflating: imgs/imgs/5545.png
#   inflating: imgs/imgs/5546.png
#   inflating: imgs/imgs/5547.png
#   inflating: imgs/imgs/5548.png
#   inflating: imgs/imgs/5549.png
#   inflating: imgs/imgs/555.png
#   inflating: imgs/imgs/5550.png
#   inflating: imgs/imgs/5551.png
#   inflating: imgs/imgs/5552.png
#   inflating: imgs/imgs/5553.png
#   inflating: imgs/imgs/5554.png
#   inflating: imgs/imgs/5555.png
#   inflating: imgs/imgs/5556.png
#   inflating: imgs/imgs/5557.png
#   inflating: imgs/imgs/5558.png
#   inflating: imgs/imgs/5559.png
#   inflating: imgs/imgs/556.png
#   inflating: imgs/imgs/5560.png
#   inflating: imgs/imgs/5561.png
#   inflating: imgs/imgs/5562.png
#   inflating: imgs/imgs/5563.png
#   inflating: imgs/imgs/5564.png
#   inflating: imgs/imgs/5565.png
#   inflating: imgs/imgs/5566.png
#   inflating: imgs/imgs/5567.png
#   inflating: imgs/imgs/5568.png
#   inflating: imgs/imgs/5569.png
#   inflating: imgs/imgs/557.png
#   inflating: imgs/imgs/5570.png
#   inflating: imgs/imgs/5571.png
#   inflating: imgs/imgs/5572.png
#   inflating: imgs/imgs/5573.png
#   inflating: imgs/imgs/5574.png
#   inflating: imgs/imgs/5575.png
#   inflating: imgs/imgs/5576.png
#   inflating: imgs/imgs/5577.png
#   inflating: imgs/imgs/5578.png
#   inflating: imgs/imgs/5579.png
#   inflating: imgs/imgs/558.png
#   inflating: imgs/imgs/5580.png
#   inflating: imgs/imgs/5581.png
#   inflating: imgs/imgs/5582.png
#   inflating: imgs/imgs/5583.png
#   inflating: imgs/imgs/5584.png
#   inflating: imgs/imgs/5585.png
#   inflating: imgs/imgs/5586.png
#   inflating: imgs/imgs/5587.png
#   inflating: imgs/imgs/5588.png
#   inflating: imgs/imgs/5589.png
#   inflating: imgs/imgs/559.png
#   inflating: imgs/imgs/5590.png
#   inflating: imgs/imgs/5591.png
#   inflating: imgs/imgs/5592.png
#   inflating: imgs/imgs/5593.png
#   inflating: imgs/imgs/5594.png
#   inflating: imgs/imgs/5595.png
#   inflating: imgs/imgs/5596.png
#   inflating: imgs/imgs/5597.png
#   inflating: imgs/imgs/5598.png
#   inflating: imgs/imgs/5599.png
#   inflating: imgs/imgs/56.png
#   inflating: imgs/imgs/560.png
#   inflating: imgs/imgs/5600.png
#   inflating: imgs/imgs/5601.png
#   inflating: imgs/imgs/5602.png
#   inflating: imgs/imgs/5603.png
#   inflating: imgs/imgs/5604.png
#   inflating: imgs/imgs/5605.png
#   inflating: imgs/imgs/5606.png
#   inflating: imgs/imgs/5607.png
#   inflating: imgs/imgs/5608.png
#   inflating: imgs/imgs/5609.png
#   inflating: imgs/imgs/561.png
#   inflating: imgs/imgs/5610.png
#   inflating: imgs/imgs/5611.png
#   inflating: imgs/imgs/5612.png
#   inflating: imgs/imgs/5613.png
#   inflating: imgs/imgs/5614.png
#   inflating: imgs/imgs/5615.png
#   inflating: imgs/imgs/5616.png
#   inflating: imgs/imgs/5617.png
#   inflating: imgs/imgs/5618.png
#   inflating: imgs/imgs/5619.png
#   inflating: imgs/imgs/562.png
#   inflating: imgs/imgs/5620.png
#   inflating: imgs/imgs/5621.png
#   inflating: imgs/imgs/5622.png
#   inflating: imgs/imgs/5623.png
#   inflating: imgs/imgs/5624.png
#   inflating: imgs/imgs/5625.png
#   inflating: imgs/imgs/5626.png
#   inflating: imgs/imgs/5627.png
#   inflating: imgs/imgs/5628.png
#   inflating: imgs/imgs/5629.png
#   inflating: imgs/imgs/563.png
#   inflating: imgs/imgs/5630.png
#   inflating: imgs/imgs/5631.png
#   inflating: imgs/imgs/5632.png
#   inflating: imgs/imgs/5633.png
#   inflating: imgs/imgs/5634.png
#   inflating: imgs/imgs/5635.png
#   inflating: imgs/imgs/5636.png
#   inflating: imgs/imgs/5637.png
#   inflating: imgs/imgs/5638.png
#   inflating: imgs/imgs/5639.png
#   inflating: imgs/imgs/564.png
#   inflating: imgs/imgs/5640.png
#   inflating: imgs/imgs/5641.png
#   inflating: imgs/imgs/5642.png
#   inflating: imgs/imgs/5643.png
#   inflating: imgs/imgs/5644.png
#   inflating: imgs/imgs/5645.png
#   inflating: imgs/imgs/5646.png
#   inflating: imgs/imgs/5647.png
#   inflating: imgs/imgs/5648.png
#   inflating: imgs/imgs/5649.png
#   inflating: imgs/imgs/565.png
#   inflating: imgs/imgs/5650.png
#   inflating: imgs/imgs/5651.png
#   inflating: imgs/imgs/5652.png
#   inflating: imgs/imgs/5653.png
#   inflating: imgs/imgs/5654.png
#   inflating: imgs/imgs/5655.png
#   inflating: imgs/imgs/5656.png
#   inflating: imgs/imgs/5657.png
#   inflating: imgs/imgs/5658.png
#   inflating: imgs/imgs/5659.png
#   inflating: imgs/imgs/566.png
#   inflating: imgs/imgs/5660.png
#   inflating: imgs/imgs/5661.png
#   inflating: imgs/imgs/5662.png
#   inflating: imgs/imgs/5663.png
#   inflating: imgs/imgs/5664.png
#   inflating: imgs/imgs/5665.png
#   inflating: imgs/imgs/5666.png
#   inflating: imgs/imgs/5667.png
#   inflating: imgs/imgs/5668.png
#   inflating: imgs/imgs/5669.png
#   inflating: imgs/imgs/567.png
#   inflating: imgs/imgs/5670.png
#   inflating: imgs/imgs/5671.png
#   inflating: imgs/imgs/5672.png
#   inflating: imgs/imgs/5673.png
#   inflating: imgs/imgs/5674.png
#   inflating: imgs/imgs/5675.png
#   inflating: imgs/imgs/5676.png
#   inflating: imgs/imgs/5677.png
#   inflating: imgs/imgs/5678.png
#   inflating: imgs/imgs/5679.png
#   inflating: imgs/imgs/568.png
#   inflating: imgs/imgs/5680.png
#   inflating: imgs/imgs/5681.png
#   inflating: imgs/imgs/5682.png
#   inflating: imgs/imgs/5683.png
#   inflating: imgs/imgs/5684.png
#   inflating: imgs/imgs/5685.png
#   inflating: imgs/imgs/5686.png
#   inflating: imgs/imgs/5687.png
#   inflating: imgs/imgs/5688.png
#   inflating: imgs/imgs/5689.png
#   inflating: imgs/imgs/569.png
#   inflating: imgs/imgs/5690.png
#   inflating: imgs/imgs/5691.png
#   inflating: imgs/imgs/5692.png
#   inflating: imgs/imgs/5693.png
#   inflating: imgs/imgs/5694.png
#   inflating: imgs/imgs/5695.png
#   inflating: imgs/imgs/5696.png
#   inflating: imgs/imgs/5697.png
#   inflating: imgs/imgs/5698.png
#   inflating: imgs/imgs/5699.png
#   inflating: imgs/imgs/57.png
#   inflating: imgs/imgs/570.png
#   inflating: imgs/imgs/5700.png
#   inflating: imgs/imgs/5701.png
#   inflating: imgs/imgs/5702.png
#   inflating: imgs/imgs/5703.png
#   inflating: imgs/imgs/5704.png
#   inflating: imgs/imgs/5705.png
#   inflating: imgs/imgs/5706.png
#   inflating: imgs/imgs/5707.png
#   inflating: imgs/imgs/5708.png
#   inflating: imgs/imgs/5709.png
#   inflating: imgs/imgs/571.png
#   inflating: imgs/imgs/5710.png
#   inflating: imgs/imgs/5711.png
#   inflating: imgs/imgs/5712.png
#   inflating: imgs/imgs/5713.png
#   inflating: imgs/imgs/5714.png
#   inflating: imgs/imgs/5715.png
#   inflating: imgs/imgs/5716.png
#   inflating: imgs/imgs/5717.png
#   inflating: imgs/imgs/5718.png
#   inflating: imgs/imgs/5719.png
#   inflating: imgs/imgs/572.png
#   inflating: imgs/imgs/5720.png
#   inflating: imgs/imgs/5721.png
#   inflating: imgs/imgs/5722.png
#   inflating: imgs/imgs/5723.png
#   inflating: imgs/imgs/5724.png
#   inflating: imgs/imgs/5725.png
#   inflating: imgs/imgs/5726.png
#   inflating: imgs/imgs/5727.png
#   inflating: imgs/imgs/5728.png
#   inflating: imgs/imgs/5729.png
#   inflating: imgs/imgs/573.png
#   inflating: imgs/imgs/5730.png
#   inflating: imgs/imgs/5731.png
#   inflating: imgs/imgs/5732.png
#   inflating: imgs/imgs/5733.png
#   inflating: imgs/imgs/5734.png
#   inflating: imgs/imgs/5735.png
#   inflating: imgs/imgs/5736.png
#   inflating: imgs/imgs/5737.png
#   inflating: imgs/imgs/5738.png
#   inflating: imgs/imgs/5739.png
#   inflating: imgs/imgs/574.png
#   inflating: imgs/imgs/5740.png
#   inflating: imgs/imgs/5741.png
#   inflating: imgs/imgs/5742.png
#   inflating: imgs/imgs/5743.png
#   inflating: imgs/imgs/5744.png
#   inflating: imgs/imgs/5745.png
#   inflating: imgs/imgs/5746.png
#   inflating: imgs/imgs/5747.png
#   inflating: imgs/imgs/5748.png
#   inflating: imgs/imgs/5749.png
#   inflating: imgs/imgs/575.png
#   inflating: imgs/imgs/5750.png
#   inflating: imgs/imgs/5751.png
#   inflating: imgs/imgs/5752.png
#   inflating: imgs/imgs/5753.png
#   inflating: imgs/imgs/5754.png
#   inflating: imgs/imgs/5755.png
#   inflating: imgs/imgs/5756.png
#   inflating: imgs/imgs/5757.png
#   inflating: imgs/imgs/5758.png
#   inflating: imgs/imgs/5759.png
#   inflating: imgs/imgs/576.png
#   inflating: imgs/imgs/5760.png
#   inflating: imgs/imgs/5761.png
#   inflating: imgs/imgs/5762.png
#   inflating: imgs/imgs/5763.png
#   inflating: imgs/imgs/5764.png
#   inflating: imgs/imgs/5765.png
#   inflating: imgs/imgs/5766.png
#   inflating: imgs/imgs/5767.png
#   inflating: imgs/imgs/5768.png
#   inflating: imgs/imgs/5769.png
#   inflating: imgs/imgs/577.png
#   inflating: imgs/imgs/5770.png
#   inflating: imgs/imgs/5771.png
#   inflating: imgs/imgs/5772.png
#   inflating: imgs/imgs/5773.png
#   inflating: imgs/imgs/5774.png
#   inflating: imgs/imgs/5775.png
#   inflating: imgs/imgs/5776.png
#   inflating: imgs/imgs/5777.png
#   inflating: imgs/imgs/5778.png
#   inflating: imgs/imgs/5779.png
#   inflating: imgs/imgs/578.png
#   inflating: imgs/imgs/5780.png
#   inflating: imgs/imgs/5781.png
#   inflating: imgs/imgs/5782.png
#   inflating: imgs/imgs/5783.png
#   inflating: imgs/imgs/5784.png
#   inflating: imgs/imgs/5785.png
#   inflating: imgs/imgs/5786.png
#   inflating: imgs/imgs/5787.png
#   inflating: imgs/imgs/5788.png
#   inflating: imgs/imgs/5789.png
#   inflating: imgs/imgs/579.png
#   inflating: imgs/imgs/5790.png
#   inflating: imgs/imgs/5791.png
#   inflating: imgs/imgs/5792.png
#   inflating: imgs/imgs/5793.png
#   inflating: imgs/imgs/5794.png
#   inflating: imgs/imgs/5795.png
#   inflating: imgs/imgs/5796.png
#   inflating: imgs/imgs/5797.png
#   inflating: imgs/imgs/5798.png
#   inflating: imgs/imgs/5799.png
#   inflating: imgs/imgs/58.png
#   inflating: imgs/imgs/580.png
#   inflating: imgs/imgs/5800.png
#   inflating: imgs/imgs/5801.png
#   inflating: imgs/imgs/5802.png
#   inflating: imgs/imgs/5803.png
#   inflating: imgs/imgs/5804.png
#   inflating: imgs/imgs/5805.png
#   inflating: imgs/imgs/5806.png
#   inflating: imgs/imgs/5807.png
#   inflating: imgs/imgs/5808.png
#   inflating: imgs/imgs/5809.png
#   inflating: imgs/imgs/581.png
#   inflating: imgs/imgs/5810.png
#   inflating: imgs/imgs/5811.png
#   inflating: imgs/imgs/5812.png
#   inflating: imgs/imgs/5813.png
#   inflating: imgs/imgs/5814.png
#   inflating: imgs/imgs/5815.png
#   inflating: imgs/imgs/5816.png
#   inflating: imgs/imgs/5817.png
#   inflating: imgs/imgs/5818.png
#   inflating: imgs/imgs/5819.png
#   inflating: imgs/imgs/582.png
#   inflating: imgs/imgs/5820.png
#   inflating: imgs/imgs/5821.png
#   inflating: imgs/imgs/5822.png
#   inflating: imgs/imgs/5823.png
#   inflating: imgs/imgs/5824.png
#   inflating: imgs/imgs/5825.png
#   inflating: imgs/imgs/5826.png
#   inflating: imgs/imgs/5827.png
#   inflating: imgs/imgs/5828.png
#   inflating: imgs/imgs/5829.png
#   inflating: imgs/imgs/583.png
#   inflating: imgs/imgs/5830.png
#   inflating: imgs/imgs/5831.png
#   inflating: imgs/imgs/5832.png
#   inflating: imgs/imgs/5833.png
#   inflating: imgs/imgs/5834.png
#   inflating: imgs/imgs/5835.png
#   inflating: imgs/imgs/5836.png
#   inflating: imgs/imgs/5837.png
#   inflating: imgs/imgs/5838.png
#   inflating: imgs/imgs/5839.png
#   inflating: imgs/imgs/584.png
#   inflating: imgs/imgs/5840.png
#   inflating: imgs/imgs/5841.png
#   inflating: imgs/imgs/5842.png
#   inflating: imgs/imgs/5843.png
#   inflating: imgs/imgs/5844.png
#   inflating: imgs/imgs/5845.png
#   inflating: imgs/imgs/5846.png
#   inflating: imgs/imgs/5847.png
#   inflating: imgs/imgs/5848.png
#   inflating: imgs/imgs/5849.png
#   inflating: imgs/imgs/585.png
#   inflating: imgs/imgs/5850.png
#   inflating: imgs/imgs/5851.png
#   inflating: imgs/imgs/5852.png
#   inflating: imgs/imgs/5853.png
#   inflating: imgs/imgs/5854.png
#   inflating: imgs/imgs/5855.png
#   inflating: imgs/imgs/5856.png
#   inflating: imgs/imgs/5857.png
#   inflating: imgs/imgs/5858.png
#   inflating: imgs/imgs/5859.png
#   inflating: imgs/imgs/586.png
#   inflating: imgs/imgs/5860.png
#   inflating: imgs/imgs/5861.png
#   inflating: imgs/imgs/5862.png
#   inflating: imgs/imgs/5863.png
#   inflating: imgs/imgs/5864.png
#   inflating: imgs/imgs/5865.png
#   inflating: imgs/imgs/5866.png
#   inflating: imgs/imgs/5867.png
#   inflating: imgs/imgs/5868.png
#   inflating: imgs/imgs/5869.png
#   inflating: imgs/imgs/587.png
#   inflating: imgs/imgs/5870.png
#   inflating: imgs/imgs/5871.png
#   inflating: imgs/imgs/5872.png
#   inflating: imgs/imgs/5873.png
#   inflating: imgs/imgs/5874.png
#   inflating: imgs/imgs/5875.png
#   inflating: imgs/imgs/5876.png
#   inflating: imgs/imgs/5877.png
#   inflating: imgs/imgs/5878.png
#   inflating: imgs/imgs/5879.png
#   inflating: imgs/imgs/588.png
#   inflating: imgs/imgs/5880.png
#   inflating: imgs/imgs/5881.png
#   inflating: imgs/imgs/5882.png
#   inflating: imgs/imgs/5883.png
#   inflating: imgs/imgs/5884.png
#   inflating: imgs/imgs/5885.png
#   inflating: imgs/imgs/5886.png
#   inflating: imgs/imgs/5887.png
#   inflating: imgs/imgs/5888.png
#   inflating: imgs/imgs/5889.png
#   inflating: imgs/imgs/589.png
#   inflating: imgs/imgs/5890.png
#   inflating: imgs/imgs/5891.png
#   inflating: imgs/imgs/5892.png
#   inflating: imgs/imgs/5893.png
#   inflating: imgs/imgs/5894.png
#   inflating: imgs/imgs/5895.png
#   inflating: imgs/imgs/5896.png
#   inflating: imgs/imgs/5897.png
#   inflating: imgs/imgs/5898.png
#   inflating: imgs/imgs/5899.png
#   inflating: imgs/imgs/59.png
#   inflating: imgs/imgs/590.png
#   inflating: imgs/imgs/5900.png
#   inflating: imgs/imgs/5901.png
#   inflating: imgs/imgs/5902.png
#   inflating: imgs/imgs/5903.png
#   inflating: imgs/imgs/5904.png
#   inflating: imgs/imgs/5905.png
#   inflating: imgs/imgs/5906.png
#   inflating: imgs/imgs/5907.png
#   inflating: imgs/imgs/5908.png
#   inflating: imgs/imgs/5909.png
#   inflating: imgs/imgs/591.png
#   inflating: imgs/imgs/5910.png
#   inflating: imgs/imgs/5911.png
#   inflating: imgs/imgs/5912.png
#   inflating: imgs/imgs/5913.png
#   inflating: imgs/imgs/5914.png
#   inflating: imgs/imgs/5915.png
#   inflating: imgs/imgs/5916.png
#   inflating: imgs/imgs/5917.png
#   inflating: imgs/imgs/5918.png
#   inflating: imgs/imgs/5919.png
#   inflating: imgs/imgs/592.png
#   inflating: imgs/imgs/5920.png
#   inflating: imgs/imgs/5921.png
#   inflating: imgs/imgs/5922.png
#   inflating: imgs/imgs/5923.png
#   inflating: imgs/imgs/5924.png
#   inflating: imgs/imgs/5925.png
#   inflating: imgs/imgs/5926.png
#   inflating: imgs/imgs/5927.png
#   inflating: imgs/imgs/5928.png
#   inflating: imgs/imgs/5929.png
#   inflating: imgs/imgs/593.png
#   inflating: imgs/imgs/5930.png
#   inflating: imgs/imgs/5931.png
#   inflating: imgs/imgs/5932.png
#   inflating: imgs/imgs/5933.png
#   inflating: imgs/imgs/5934.png
#   inflating: imgs/imgs/5935.png
#   inflating: imgs/imgs/5936.png
#   inflating: imgs/imgs/5937.png
#   inflating: imgs/imgs/5938.png
#   inflating: imgs/imgs/5939.png
#   inflating: imgs/imgs/594.png
#   inflating: imgs/imgs/5940.png
#   inflating: imgs/imgs/5941.png
#   inflating: imgs/imgs/5942.png
#   inflating: imgs/imgs/5943.png
#   inflating: imgs/imgs/5944.png
#   inflating: imgs/imgs/5945.png
#   inflating: imgs/imgs/5946.png
#   inflating: imgs/imgs/5947.png
#   inflating: imgs/imgs/5948.png
#   inflating: imgs/imgs/5949.png
#   inflating: imgs/imgs/595.png
#   inflating: imgs/imgs/5950.png
#   inflating: imgs/imgs/5951.png
#   inflating: imgs/imgs/5952.png
#   inflating: imgs/imgs/5953.png
#   inflating: imgs/imgs/5954.png
#   inflating: imgs/imgs/5955.png
#   inflating: imgs/imgs/5956.png
#   inflating: imgs/imgs/5957.png
#   inflating: imgs/imgs/5958.png
#   inflating: imgs/imgs/5959.png
#   inflating: imgs/imgs/596.png
#   inflating: imgs/imgs/5960.png
#   inflating: imgs/imgs/5961.png
#   inflating: imgs/imgs/5962.png
#   inflating: imgs/imgs/5963.png
#   inflating: imgs/imgs/5964.png
#   inflating: imgs/imgs/5965.png
#   inflating: imgs/imgs/5966.png
#   inflating: imgs/imgs/5967.png
#   inflating: imgs/imgs/5968.png
#   inflating: imgs/imgs/5969.png
#   inflating: imgs/imgs/597.png
#   inflating: imgs/imgs/5970.png
#   inflating: imgs/imgs/5971.png
#   inflating: imgs/imgs/5972.png
#   inflating: imgs/imgs/5973.png
#   inflating: imgs/imgs/5974.png
#   inflating: imgs/imgs/5975.png
#   inflating: imgs/imgs/5976.png
#   inflating: imgs/imgs/5977.png
#   inflating: imgs/imgs/5978.png
#   inflating: imgs/imgs/5979.png
#   inflating: imgs/imgs/598.png
#   inflating: imgs/imgs/5980.png
#   inflating: imgs/imgs/5981.png
#   inflating: imgs/imgs/5982.png
#   inflating: imgs/imgs/5983.png
#   inflating: imgs/imgs/5984.png
#   inflating: imgs/imgs/5985.png
#   inflating: imgs/imgs/5986.png
#   inflating: imgs/imgs/5987.png
#   inflating: imgs/imgs/5988.png
#   inflating: imgs/imgs/5989.png
#   inflating: imgs/imgs/599.png
#   inflating: imgs/imgs/5990.png
#   inflating: imgs/imgs/5991.png
#   inflating: imgs/imgs/5992.png
#   inflating: imgs/imgs/5993.png
#   inflating: imgs/imgs/5994.png
#   inflating: imgs/imgs/5995.png
#   inflating: imgs/imgs/5996.png
#   inflating: imgs/imgs/5997.png
#   inflating: imgs/imgs/5998.png
#   inflating: imgs/imgs/5999.png
#   inflating: imgs/imgs/6.png
#   inflating: imgs/imgs/60.png
#   inflating: imgs/imgs/600.png
#   inflating: imgs/imgs/6000.png
#   inflating: imgs/imgs/6001.png
#   inflating: imgs/imgs/6002.png
#   inflating: imgs/imgs/6003.png
#   inflating: imgs/imgs/6004.png
#   inflating: imgs/imgs/6005.png
#   inflating: imgs/imgs/6006.png
#   inflating: imgs/imgs/6007.png
#   inflating: imgs/imgs/6008.png
#   inflating: imgs/imgs/6009.png
#   inflating: imgs/imgs/601.png
#   inflating: imgs/imgs/6010.png
#   inflating: imgs/imgs/6011.png
#   inflating: imgs/imgs/6012.png
#   inflating: imgs/imgs/6013.png
#   inflating: imgs/imgs/6014.png
#   inflating: imgs/imgs/6015.png
#   inflating: imgs/imgs/6016.png
#   inflating: imgs/imgs/6017.png
#   inflating: imgs/imgs/6018.png
#   inflating: imgs/imgs/6019.png
#   inflating: imgs/imgs/602.png
#   inflating: imgs/imgs/6020.png
#   inflating: imgs/imgs/6021.png
#   inflating: imgs/imgs/6022.png
#   inflating: imgs/imgs/6023.png
#   inflating: imgs/imgs/6024.png
#   inflating: imgs/imgs/6025.png
#   inflating: imgs/imgs/6026.png
#   inflating: imgs/imgs/6027.png
#   inflating: imgs/imgs/6028.png
#   inflating: imgs/imgs/6029.png
#   inflating: imgs/imgs/603.png
#   inflating: imgs/imgs/6030.png
#   inflating: imgs/imgs/6031.png
#   inflating: imgs/imgs/6032.png
#   inflating: imgs/imgs/6033.png
#   inflating: imgs/imgs/6034.png
#   inflating: imgs/imgs/6035.png
#   inflating: imgs/imgs/6036.png
#   inflating: imgs/imgs/6037.png
#   inflating: imgs/imgs/6038.png
#   inflating: imgs/imgs/6039.png
#   inflating: imgs/imgs/604.png
#   inflating: imgs/imgs/6040.png
#   inflating: imgs/imgs/6041.png
#   inflating: imgs/imgs/6042.png
#   inflating: imgs/imgs/6043.png
#   inflating: imgs/imgs/6044.png
#   inflating: imgs/imgs/6045.png
#   inflating: imgs/imgs/6046.png
#   inflating: imgs/imgs/6047.png
#   inflating: imgs/imgs/6048.png
#   inflating: imgs/imgs/6049.png
#   inflating: imgs/imgs/605.png
#   inflating: imgs/imgs/6050.png
#   inflating: imgs/imgs/6051.png
#   inflating: imgs/imgs/6052.png
#   inflating: imgs/imgs/6053.png
#   inflating: imgs/imgs/6054.png
#   inflating: imgs/imgs/6055.png
#   inflating: imgs/imgs/6056.png
#   inflating: imgs/imgs/6057.png
#   inflating: imgs/imgs/6058.png
#   inflating: imgs/imgs/6059.png
#   inflating: imgs/imgs/606.png
#   inflating: imgs/imgs/6060.png
#   inflating: imgs/imgs/6061.png
#   inflating: imgs/imgs/6062.png
#   inflating: imgs/imgs/6063.png
#   inflating: imgs/imgs/6064.png
#   inflating: imgs/imgs/6065.png
#   inflating: imgs/imgs/6066.png
#   inflating: imgs/imgs/6067.png
#   inflating: imgs/imgs/6068.png
#   inflating: imgs/imgs/6069.png
#   inflating: imgs/imgs/607.png
#   inflating: imgs/imgs/6070.png
#   inflating: imgs/imgs/6071.png
#   inflating: imgs/imgs/6072.png
#   inflating: imgs/imgs/6073.png
#   inflating: imgs/imgs/6074.png
#   inflating: imgs/imgs/6075.png
#   inflating: imgs/imgs/6076.png
#   inflating: imgs/imgs/6077.png
#   inflating: imgs/imgs/6078.png
#   inflating: imgs/imgs/6079.png
#   inflating: imgs/imgs/608.png
#   inflating: imgs/imgs/6080.png
#   inflating: imgs/imgs/6081.png
#   inflating: imgs/imgs/6082.png
#   inflating: imgs/imgs/6083.png
#   inflating: imgs/imgs/6084.png
#   inflating: imgs/imgs/6085.png
#   inflating: imgs/imgs/6086.png
#   inflating: imgs/imgs/6087.png
#   inflating: imgs/imgs/6088.png
#   inflating: imgs/imgs/6089.png
#   inflating: imgs/imgs/609.png
#   inflating: imgs/imgs/6090.png
#   inflating: imgs/imgs/6091.png
#   inflating: imgs/imgs/6092.png
#   inflating: imgs/imgs/6093.png
#   inflating: imgs/imgs/6094.png
#   inflating: imgs/imgs/6095.png
#   inflating: imgs/imgs/6096.png
#   inflating: imgs/imgs/6097.png
#   inflating: imgs/imgs/6098.png
#   inflating: imgs/imgs/6099.png
#   inflating: imgs/imgs/61.png
#   inflating: imgs/imgs/610.png
#   inflating: imgs/imgs/6100.png
#   inflating: imgs/imgs/6101.png
#   inflating: imgs/imgs/6102.png
#   inflating: imgs/imgs/6103.png
#   inflating: imgs/imgs/6104.png
#   inflating: imgs/imgs/6105.png
#   inflating: imgs/imgs/6106.png
#   inflating: imgs/imgs/6107.png
#   inflating: imgs/imgs/6108.png
#   inflating: imgs/imgs/6109.png
#   inflating: imgs/imgs/611.png
#   inflating: imgs/imgs/6110.png
#   inflating: imgs/imgs/6111.png
#   inflating: imgs/imgs/6112.png
#   inflating: imgs/imgs/6113.png
#   inflating: imgs/imgs/6114.png
#   inflating: imgs/imgs/6115.png
#   inflating: imgs/imgs/6116.png
#   inflating: imgs/imgs/6117.png
#   inflating: imgs/imgs/6118.png
#   inflating: imgs/imgs/6119.png
#   inflating: imgs/imgs/612.png
#   inflating: imgs/imgs/6120.png
#   inflating: imgs/imgs/6121.png
#   inflating: imgs/imgs/6122.png
#   inflating: imgs/imgs/6123.png
#   inflating: imgs/imgs/6124.png
#   inflating: imgs/imgs/6125.png
#   inflating: imgs/imgs/6126.png
#   inflating: imgs/imgs/6127.png
#   inflating: imgs/imgs/6128.png
#   inflating: imgs/imgs/6129.png
#   inflating: imgs/imgs/613.png
#   inflating: imgs/imgs/6130.png
#   inflating: imgs/imgs/6131.png
#   inflating: imgs/imgs/6132.png
#   inflating: imgs/imgs/6133.png
#   inflating: imgs/imgs/6134.png
#   inflating: imgs/imgs/6135.png
#   inflating: imgs/imgs/6136.png
#   inflating: imgs/imgs/6137.png
#   inflating: imgs/imgs/6138.png
#   inflating: imgs/imgs/6139.png
#   inflating: imgs/imgs/614.png
#   inflating: imgs/imgs/6140.png
#   inflating: imgs/imgs/6141.png
#   inflating: imgs/imgs/6142.png
#   inflating: imgs/imgs/6143.png
#   inflating: imgs/imgs/6144.png
#   inflating: imgs/imgs/6145.png
#   inflating: imgs/imgs/6146.png
#   inflating: imgs/imgs/6147.png
#   inflating: imgs/imgs/6148.png
#   inflating: imgs/imgs/6149.png
#   inflating: imgs/imgs/615.png
#   inflating: imgs/imgs/6150.png
#   inflating: imgs/imgs/6151.png
#   inflating: imgs/imgs/6152.png
#   inflating: imgs/imgs/6153.png
#   inflating: imgs/imgs/6154.png
#   inflating: imgs/imgs/6155.png
#   inflating: imgs/imgs/6156.png
#   inflating: imgs/imgs/6157.png
#   inflating: imgs/imgs/6158.png
#   inflating: imgs/imgs/6159.png
#   inflating: imgs/imgs/616.png
#   inflating: imgs/imgs/6160.png
#   inflating: imgs/imgs/6161.png
#   inflating: imgs/imgs/6162.png
#   inflating: imgs/imgs/6163.png
#   inflating: imgs/imgs/6164.png
#   inflating: imgs/imgs/6165.png
#   inflating: imgs/imgs/6166.png
#   inflating: imgs/imgs/6167.png
#   inflating: imgs/imgs/6168.png
#   inflating: imgs/imgs/6169.png
#   inflating: imgs/imgs/617.png
#   inflating: imgs/imgs/6170.png
#   inflating: imgs/imgs/6171.png
#   inflating: imgs/imgs/6172.png
#   inflating: imgs/imgs/6173.png
#   inflating: imgs/imgs/6174.png
#   inflating: imgs/imgs/6175.png
#   inflating: imgs/imgs/6176.png
#   inflating: imgs/imgs/6177.png
#   inflating: imgs/imgs/6178.png
#   inflating: imgs/imgs/6179.png
#   inflating: imgs/imgs/618.png
#   inflating: imgs/imgs/6180.png
#   inflating: imgs/imgs/6181.png
#   inflating: imgs/imgs/6182.png
#   inflating: imgs/imgs/6183.png
#   inflating: imgs/imgs/6184.png
#   inflating: imgs/imgs/6185.png
#   inflating: imgs/imgs/6186.png
#   inflating: imgs/imgs/6187.png
#   inflating: imgs/imgs/6188.png
#   inflating: imgs/imgs/6189.png
#   inflating: imgs/imgs/619.png
#   inflating: imgs/imgs/6190.png
#   inflating: imgs/imgs/6191.png
#   inflating: imgs/imgs/6192.png
#   inflating: imgs/imgs/6193.png
#   inflating: imgs/imgs/6194.png
#   inflating: imgs/imgs/6195.png
#   inflating: imgs/imgs/6196.png
#   inflating: imgs/imgs/6197.png
#   inflating: imgs/imgs/6198.png
#   inflating: imgs/imgs/6199.png
#   inflating: imgs/imgs/62.png
#   inflating: imgs/imgs/620.png
#   inflating: imgs/imgs/6200.png
#   inflating: imgs/imgs/6201.png
#   inflating: imgs/imgs/6202.png
#   inflating: imgs/imgs/6203.png
#   inflating: imgs/imgs/6204.png
#   inflating: imgs/imgs/6205.png
#   inflating: imgs/imgs/6206.png
#   inflating: imgs/imgs/6207.png
#   inflating: imgs/imgs/6208.png
#   inflating: imgs/imgs/6209.png
#   inflating: imgs/imgs/621.png
#   inflating: imgs/imgs/6210.png
#   inflating: imgs/imgs/6211.png
#   inflating: imgs/imgs/6212.png
#   inflating: imgs/imgs/6213.png
#   inflating: imgs/imgs/6214.png
#   inflating: imgs/imgs/6215.png
#   inflating: imgs/imgs/6216.png
#   inflating: imgs/imgs/6217.png
#   inflating: imgs/imgs/6218.png
#   inflating: imgs/imgs/6219.png
#   inflating: imgs/imgs/622.png
#   inflating: imgs/imgs/6220.png
#   inflating: imgs/imgs/6221.png
#   inflating: imgs/imgs/6222.png
#   inflating: imgs/imgs/6223.png
#   inflating: imgs/imgs/6224.png
#   inflating: imgs/imgs/6225.png
#   inflating: imgs/imgs/6226.png
#   inflating: imgs/imgs/6227.png
#   inflating: imgs/imgs/6228.png
#   inflating: imgs/imgs/6229.png
#   inflating: imgs/imgs/623.png
#   inflating: imgs/imgs/6230.png
#   inflating: imgs/imgs/6231.png
#   inflating: imgs/imgs/6232.png
#   inflating: imgs/imgs/6233.png
#   inflating: imgs/imgs/6234.png
#   inflating: imgs/imgs/6235.png
#   inflating: imgs/imgs/6236.png
#   inflating: imgs/imgs/6237.png
#   inflating: imgs/imgs/6238.png
#   inflating: imgs/imgs/6239.png
#   inflating: imgs/imgs/624.png
#   inflating: imgs/imgs/6240.png
#   inflating: imgs/imgs/6241.png
#   inflating: imgs/imgs/6242.png
#   inflating: imgs/imgs/6243.png
#   inflating: imgs/imgs/6244.png
#   inflating: imgs/imgs/6245.png
#   inflating: imgs/imgs/6246.png
#   inflating: imgs/imgs/6247.png
#   inflating: imgs/imgs/6248.png
#   inflating: imgs/imgs/6249.png
#   inflating: imgs/imgs/625.png
#   inflating: imgs/imgs/6250.png
#   inflating: imgs/imgs/6251.png
#   inflating: imgs/imgs/6252.png
#   inflating: imgs/imgs/6253.png
#   inflating: imgs/imgs/6254.png
#   inflating: imgs/imgs/6255.png
#   inflating: imgs/imgs/6256.png
#   inflating: imgs/imgs/6257.png
#   inflating: imgs/imgs/6258.png
#   inflating: imgs/imgs/6259.png
#   inflating: imgs/imgs/626.png
#   inflating: imgs/imgs/6260.png
#   inflating: imgs/imgs/6261.png
#   inflating: imgs/imgs/6262.png
#   inflating: imgs/imgs/6263.png
#   inflating: imgs/imgs/6264.png
#   inflating: imgs/imgs/6265.png
#   inflating: imgs/imgs/6266.png
#   inflating: imgs/imgs/6267.png
#   inflating: imgs/imgs/6268.png
#   inflating: imgs/imgs/6269.png
#   inflating: imgs/imgs/627.png
#   inflating: imgs/imgs/6270.png
#   inflating: imgs/imgs/6271.png
#   inflating: imgs/imgs/6272.png
#   inflating: imgs/imgs/6273.png
#   inflating: imgs/imgs/6274.png
#   inflating: imgs/imgs/6275.png
#   inflating: imgs/imgs/6276.png
#   inflating: imgs/imgs/6277.png
#   inflating: imgs/imgs/6278.png
#   inflating: imgs/imgs/6279.png
#   inflating: imgs/imgs/628.png
#   inflating: imgs/imgs/6280.png
#   inflating: imgs/imgs/6281.png
#   inflating: imgs/imgs/6282.png
#   inflating: imgs/imgs/6283.png
#   inflating: imgs/imgs/6284.png
#   inflating: imgs/imgs/6285.png
#   inflating: imgs/imgs/6286.png
#   inflating: imgs/imgs/6287.png
#   inflating: imgs/imgs/6288.png
#   inflating: imgs/imgs/6289.png
#   inflating: imgs/imgs/629.png
#   inflating: imgs/imgs/6290.png
#   inflating: imgs/imgs/6291.png
#   inflating: imgs/imgs/6292.png
#   inflating: imgs/imgs/6293.png
#   inflating: imgs/imgs/6294.png
#   inflating: imgs/imgs/6295.png
#   inflating: imgs/imgs/6296.png
#   inflating: imgs/imgs/6297.png
#   inflating: imgs/imgs/6298.png
#   inflating: imgs/imgs/6299.png
#   inflating: imgs/imgs/63.png
#   inflating: imgs/imgs/630.png
#   inflating: imgs/imgs/6300.png
#   inflating: imgs/imgs/6301.png
#   inflating: imgs/imgs/6302.png
#   inflating: imgs/imgs/6303.png
#   inflating: imgs/imgs/6304.png
#   inflating: imgs/imgs/6305.png
#   inflating: imgs/imgs/6306.png
#   inflating: imgs/imgs/6307.png
#   inflating: imgs/imgs/6308.png
#   inflating: imgs/imgs/6309.png
#   inflating: imgs/imgs/631.png
#   inflating: imgs/imgs/6310.png
#   inflating: imgs/imgs/6311.png
#   inflating: imgs/imgs/6312.png
#   inflating: imgs/imgs/6313.png
#   inflating: imgs/imgs/6314.png
#   inflating: imgs/imgs/6315.png
#   inflating: imgs/imgs/6316.png
#   inflating: imgs/imgs/6317.png
#   inflating: imgs/imgs/6318.png
#   inflating: imgs/imgs/6319.png
#   inflating: imgs/imgs/632.png
#   inflating: imgs/imgs/6320.png
#   inflating: imgs/imgs/6321.png
#   inflating: imgs/imgs/6322.png
#   inflating: imgs/imgs/6323.png
#   inflating: imgs/imgs/6324.png
#   inflating: imgs/imgs/6325.png
#   inflating: imgs/imgs/6326.png
#   inflating: imgs/imgs/6327.png
#   inflating: imgs/imgs/6328.png
#   inflating: imgs/imgs/6329.png
#   inflating: imgs/imgs/633.png
#   inflating: imgs/imgs/6330.png
#   inflating: imgs/imgs/6331.png
#   inflating: imgs/imgs/6332.png
#   inflating: imgs/imgs/6333.png
#   inflating: imgs/imgs/6334.png
#   inflating: imgs/imgs/6335.png
#   inflating: imgs/imgs/6336.png
#   inflating: imgs/imgs/6337.png
#   inflating: imgs/imgs/6338.png
#   inflating: imgs/imgs/6339.png
#   inflating: imgs/imgs/634.png
#   inflating: imgs/imgs/6340.png
#   inflating: imgs/imgs/6341.png
#   inflating: imgs/imgs/6342.png
#   inflating: imgs/imgs/6343.png
#   inflating: imgs/imgs/6344.png
#   inflating: imgs/imgs/6345.png
#   inflating: imgs/imgs/6346.png
#   inflating: imgs/imgs/6347.png
#   inflating: imgs/imgs/6348.png
#   inflating: imgs/imgs/6349.png
#   inflating: imgs/imgs/635.png
#   inflating: imgs/imgs/6350.png
#   inflating: imgs/imgs/6351.png
#   inflating: imgs/imgs/6352.png
#   inflating: imgs/imgs/6353.png
#   inflating: imgs/imgs/6354.png
#   inflating: imgs/imgs/6355.png
#   inflating: imgs/imgs/6356.png
#   inflating: imgs/imgs/6357.png
#   inflating: imgs/imgs/6358.png
#   inflating: imgs/imgs/6359.png
#   inflating: imgs/imgs/636.png
#   inflating: imgs/imgs/6360.png
#   inflating: imgs/imgs/6361.png
#   inflating: imgs/imgs/6362.png
#   inflating: imgs/imgs/6363.png
#   inflating: imgs/imgs/6364.png
#   inflating: imgs/imgs/6365.png
#   inflating: imgs/imgs/6366.png
#   inflating: imgs/imgs/6367.png
#   inflating: imgs/imgs/6368.png
#   inflating: imgs/imgs/6369.png
#   inflating: imgs/imgs/637.png
#   inflating: imgs/imgs/6370.png
#   inflating: imgs/imgs/6371.png
#   inflating: imgs/imgs/6372.png
#   inflating: imgs/imgs/6373.png
#   inflating: imgs/imgs/6374.png
#   inflating: imgs/imgs/6375.png
#   inflating: imgs/imgs/6376.png
#   inflating: imgs/imgs/6377.png
#   inflating: imgs/imgs/6378.png
#   inflating: imgs/imgs/6379.png
#   inflating: imgs/imgs/638.png
#   inflating: imgs/imgs/6380.png
#   inflating: imgs/imgs/6381.png
#   inflating: imgs/imgs/6382.png
#   inflating: imgs/imgs/6383.png
#   inflating: imgs/imgs/6384.png
#   inflating: imgs/imgs/6385.png
#   inflating: imgs/imgs/6386.png
#   inflating: imgs/imgs/6387.png
#   inflating: imgs/imgs/6388.png
#   inflating: imgs/imgs/6389.png
#   inflating: imgs/imgs/639.png
#   inflating: imgs/imgs/6390.png
#   inflating: imgs/imgs/6391.png
#   inflating: imgs/imgs/6392.png
#   inflating: imgs/imgs/6393.png
#   inflating: imgs/imgs/6394.png
#   inflating: imgs/imgs/6395.png
#   inflating: imgs/imgs/6396.png
#   inflating: imgs/imgs/6397.png
#   inflating: imgs/imgs/6398.png
#   inflating: imgs/imgs/6399.png
#   inflating: imgs/imgs/64.png
#   inflating: imgs/imgs/640.png
#   inflating: imgs/imgs/6400.png
#   inflating: imgs/imgs/6401.png
#   inflating: imgs/imgs/6402.png
#   inflating: imgs/imgs/6403.png
#   inflating: imgs/imgs/6404.png
#   inflating: imgs/imgs/6405.png
#   inflating: imgs/imgs/6406.png
#   inflating: imgs/imgs/6407.png
#   inflating: imgs/imgs/6408.png
#   inflating: imgs/imgs/6409.png
#   inflating: imgs/imgs/641.png
#   inflating: imgs/imgs/6410.png
#   inflating: imgs/imgs/6411.png
#   inflating: imgs/imgs/6412.png
#   inflating: imgs/imgs/6413.png
#   inflating: imgs/imgs/6414.png
#   inflating: imgs/imgs/6415.png
#   inflating: imgs/imgs/6416.png
#   inflating: imgs/imgs/6417.png
#   inflating: imgs/imgs/6418.png
#   inflating: imgs/imgs/6419.png
#   inflating: imgs/imgs/642.png
#   inflating: imgs/imgs/6420.png
#   inflating: imgs/imgs/6421.png
#   inflating: imgs/imgs/6422.png
#   inflating: imgs/imgs/6423.png
#   inflating: imgs/imgs/6424.png
#   inflating: imgs/imgs/6425.png
#   inflating: imgs/imgs/6426.png
#   inflating: imgs/imgs/6427.png
#   inflating: imgs/imgs/6428.png
#   inflating: imgs/imgs/6429.png
#   inflating: imgs/imgs/643.png
#   inflating: imgs/imgs/6430.png
#   inflating: imgs/imgs/6431.png
#   inflating: imgs/imgs/6432.png
#   inflating: imgs/imgs/6433.png
#   inflating: imgs/imgs/6434.png
#   inflating: imgs/imgs/6435.png
#   inflating: imgs/imgs/6436.png
#   inflating: imgs/imgs/6437.png
#   inflating: imgs/imgs/6438.png
#   inflating: imgs/imgs/6439.png
#   inflating: imgs/imgs/644.png
#   inflating: imgs/imgs/6440.png
#   inflating: imgs/imgs/6441.png
#   inflating: imgs/imgs/6442.png
#   inflating: imgs/imgs/6443.png
#   inflating: imgs/imgs/6444.png
#   inflating: imgs/imgs/6445.png
#   inflating: imgs/imgs/6446.png
#   inflating: imgs/imgs/6447.png
#   inflating: imgs/imgs/6448.png
#   inflating: imgs/imgs/6449.png
#   inflating: imgs/imgs/645.png
#   inflating: imgs/imgs/6450.png
#   inflating: imgs/imgs/6451.png
#   inflating: imgs/imgs/6452.png
#   inflating: imgs/imgs/6453.png
#   inflating: imgs/imgs/6454.png
#   inflating: imgs/imgs/6455.png
#   inflating: imgs/imgs/6456.png
#   inflating: imgs/imgs/6457.png
#   inflating: imgs/imgs/6458.png
#   inflating: imgs/imgs/6459.png
#   inflating: imgs/imgs/646.png
#   inflating: imgs/imgs/6460.png
#   inflating: imgs/imgs/6461.png
#   inflating: imgs/imgs/6462.png
#   inflating: imgs/imgs/6463.png
#   inflating: imgs/imgs/6464.png
#   inflating: imgs/imgs/6465.png
#   inflating: imgs/imgs/6466.png
#   inflating: imgs/imgs/6467.png
#   inflating: imgs/imgs/6468.png
#   inflating: imgs/imgs/6469.png
#   inflating: imgs/imgs/647.png
#   inflating: imgs/imgs/6470.png
#   inflating: imgs/imgs/6471.png
#   inflating: imgs/imgs/6472.png
#   inflating: imgs/imgs/6473.png
#   inflating: imgs/imgs/6474.png
#   inflating: imgs/imgs/6475.png
#   inflating: imgs/imgs/6476.png
#   inflating: imgs/imgs/6477.png
#   inflating: imgs/imgs/6478.png
#   inflating: imgs/imgs/6479.png
#   inflating: imgs/imgs/648.png
#   inflating: imgs/imgs/6480.png
#   inflating: imgs/imgs/6481.png
#   inflating: imgs/imgs/6482.png
#   inflating: imgs/imgs/6483.png
#   inflating: imgs/imgs/6484.png
#   inflating: imgs/imgs/6485.png
#   inflating: imgs/imgs/6486.png
#   inflating: imgs/imgs/6487.png
#   inflating: imgs/imgs/6488.png
#   inflating: imgs/imgs/6489.png
#   inflating: imgs/imgs/649.png
#   inflating: imgs/imgs/6490.png
#   inflating: imgs/imgs/6491.png
#   inflating: imgs/imgs/6492.png
#   inflating: imgs/imgs/6493.png
#   inflating: imgs/imgs/6494.png
#   inflating: imgs/imgs/6495.png
#   inflating: imgs/imgs/6496.png
#   inflating: imgs/imgs/6497.png
#   inflating: imgs/imgs/6498.png
#   inflating: imgs/imgs/6499.png
#   inflating: imgs/imgs/65.png
#   inflating: imgs/imgs/650.png
#   inflating: imgs/imgs/6500.png
#   inflating: imgs/imgs/6501.png
#   inflating: imgs/imgs/6502.png
#   inflating: imgs/imgs/6503.png
#   inflating: imgs/imgs/6504.png
#   inflating: imgs/imgs/6505.png
#   inflating: imgs/imgs/6506.png
#   inflating: imgs/imgs/6507.png
#   inflating: imgs/imgs/6508.png
#   inflating: imgs/imgs/6509.png
#   inflating: imgs/imgs/651.png
#   inflating: imgs/imgs/6510.png
#   inflating: imgs/imgs/6511.png
#   inflating: imgs/imgs/6512.png
#   inflating: imgs/imgs/6513.png
#   inflating: imgs/imgs/6514.png
#   inflating: imgs/imgs/6515.png
#   inflating: imgs/imgs/6516.png
#   inflating: imgs/imgs/6517.png
#   inflating: imgs/imgs/6518.png
#   inflating: imgs/imgs/6519.png
#   inflating: imgs/imgs/652.png
#   inflating: imgs/imgs/6520.png
#   inflating: imgs/imgs/6521.png
#   inflating: imgs/imgs/6522.png
#   inflating: imgs/imgs/6523.png
#   inflating: imgs/imgs/6524.png
#   inflating: imgs/imgs/6525.png
#   inflating: imgs/imgs/6526.png
#   inflating: imgs/imgs/6527.png
#   inflating: imgs/imgs/6528.png
#   inflating: imgs/imgs/6529.png
#   inflating: imgs/imgs/653.png
#   inflating: imgs/imgs/6530.png
#   inflating: imgs/imgs/6531.png
#   inflating: imgs/imgs/6532.png
#   inflating: imgs/imgs/6533.png
#   inflating: imgs/imgs/6534.png
#   inflating: imgs/imgs/6535.png
#   inflating: imgs/imgs/6536.png
#   inflating: imgs/imgs/6537.png
#   inflating: imgs/imgs/6538.png
#   inflating: imgs/imgs/6539.png
#   inflating: imgs/imgs/654.png
#   inflating: imgs/imgs/6540.png
#   inflating: imgs/imgs/6541.png
#   inflating: imgs/imgs/6542.png
#   inflating: imgs/imgs/6543.png
#   inflating: imgs/imgs/6544.png
#   inflating: imgs/imgs/6545.png
#   inflating: imgs/imgs/6546.png
#   inflating: imgs/imgs/6547.png
#   inflating: imgs/imgs/6548.png
#   inflating: imgs/imgs/6549.png
#   inflating: imgs/imgs/655.png
#   inflating: imgs/imgs/6550.png
#   inflating: imgs/imgs/6551.png
#   inflating: imgs/imgs/6552.png
#   inflating: imgs/imgs/6553.png
#   inflating: imgs/imgs/6554.png
#   inflating: imgs/imgs/6555.png
#   inflating: imgs/imgs/6556.png
#   inflating: imgs/imgs/6557.png
#   inflating: imgs/imgs/6558.png
#   inflating: imgs/imgs/6559.png
#   inflating: imgs/imgs/656.png
#   inflating: imgs/imgs/6560.png
#   inflating: imgs/imgs/6561.png
#   inflating: imgs/imgs/6562.png
#   inflating: imgs/imgs/6563.png
#   inflating: imgs/imgs/6564.png
#   inflating: imgs/imgs/6565.png
#   inflating: imgs/imgs/6566.png
#   inflating: imgs/imgs/6567.png
#   inflating: imgs/imgs/6568.png
#   inflating: imgs/imgs/6569.png
#   inflating: imgs/imgs/657.png
#   inflating: imgs/imgs/6570.png
#   inflating: imgs/imgs/6571.png
#   inflating: imgs/imgs/6572.png
#   inflating: imgs/imgs/6573.png
#   inflating: imgs/imgs/6574.png
#   inflating: imgs/imgs/6575.png
#   inflating: imgs/imgs/6576.png
#   inflating: imgs/imgs/6577.png
#   inflating: imgs/imgs/6578.png
#   inflating: imgs/imgs/6579.png
#   inflating: imgs/imgs/658.png
#   inflating: imgs/imgs/6580.png
#   inflating: imgs/imgs/6581.png
#   inflating: imgs/imgs/6582.png
#   inflating: imgs/imgs/6583.png
#   inflating: imgs/imgs/6584.png
#   inflating: imgs/imgs/6585.png
#   inflating: imgs/imgs/6586.png
#   inflating: imgs/imgs/6587.png
#   inflating: imgs/imgs/6588.png
#   inflating: imgs/imgs/6589.png
#   inflating: imgs/imgs/659.png
#   inflating: imgs/imgs/6590.png
#   inflating: imgs/imgs/6591.png
#   inflating: imgs/imgs/6592.png
#   inflating: imgs/imgs/6593.png
#   inflating: imgs/imgs/6594.png
#   inflating: imgs/imgs/6595.png
#   inflating: imgs/imgs/6596.png
#   inflating: imgs/imgs/6597.png
#   inflating: imgs/imgs/6598.png
#   inflating: imgs/imgs/6599.png
#   inflating: imgs/imgs/66.png
#   inflating: imgs/imgs/660.png
#   inflating: imgs/imgs/6600.png
#   inflating: imgs/imgs/6601.png
#   inflating: imgs/imgs/6602.png
#   inflating: imgs/imgs/6603.png
#   inflating: imgs/imgs/6604.png
#   inflating: imgs/imgs/6605.png
#   inflating: imgs/imgs/6606.png
#   inflating: imgs/imgs/6607.png
#   inflating: imgs/imgs/6608.png
#   inflating: imgs/imgs/6609.png
#   inflating: imgs/imgs/661.png
#   inflating: imgs/imgs/6610.png
#   inflating: imgs/imgs/6611.png
#   inflating: imgs/imgs/6612.png
#   inflating: imgs/imgs/6613.png
#   inflating: imgs/imgs/6614.png
#   inflating: imgs/imgs/6615.png
#   inflating: imgs/imgs/6616.png
#   inflating: imgs/imgs/6617.png
#   inflating: imgs/imgs/6618.png
#   inflating: imgs/imgs/6619.png
#   inflating: imgs/imgs/662.png
#   inflating: imgs/imgs/6620.png
#   inflating: imgs/imgs/6621.png
#   inflating: imgs/imgs/6622.png
#   inflating: imgs/imgs/6623.png
#   inflating: imgs/imgs/6624.png
#   inflating: imgs/imgs/6625.png
#   inflating: imgs/imgs/6626.png
#   inflating: imgs/imgs/6627.png
#   inflating: imgs/imgs/6628.png
#   inflating: imgs/imgs/6629.png
#   inflating: imgs/imgs/663.png
#   inflating: imgs/imgs/6630.png
#   inflating: imgs/imgs/6631.png
#   inflating: imgs/imgs/6632.png
#   inflating: imgs/imgs/6633.png
#   inflating: imgs/imgs/6634.png
# ...
#   inflating: imgs/imgs/9621.png
#   inflating: imgs/imgs/9622.png
#   inflating: imgs/imgs/9623.png
#   inflating: imgs/imgs/9624.png
#   inflating: imgs/imgs/9625.png
#   inflating: imgs/imgs/9626.png
#   inflating: imgs/imgs/9627.png
#   inflating: imgs/imgs/9628.png
#   inflating: imgs/imgs/9629.png
#   inflating: imgs/imgs/963.png
#   inflating: imgs/imgs/9630.png
#   inflating: imgs/imgs/9631.png
#   inflating: imgs/imgs/9632.png
#   inflating: imgs/imgs/9633.png
#   inflating: imgs/imgs/9634.png
#   inflating: imgs/imgs/9635.png
#   inflating: imgs/imgs/9636.png
#   inflating: imgs/imgs/9637.png
#   inflating: imgs/imgs/9638.png
#   inflating: imgs/imgs/9639.png
#   inflating: imgs/imgs/964.png
#   inflating: imgs/imgs/9640.png
#   inflating: imgs/imgs/9641.png
#   inflating: imgs/imgs/9642.png
#   inflating: imgs/imgs/9643.png
#   inflating: imgs/imgs/9644.png
#   inflating: imgs/imgs/9645.png
#   inflating: imgs/imgs/9646.png
#   inflating: imgs/imgs/9647.png
#   inflating: imgs/imgs/9648.png
#   inflating: imgs/imgs/9649.png
#   inflating: imgs/imgs/965.png
#   inflating: imgs/imgs/9650.png
#   inflating: imgs/imgs/9651.png
#   inflating: imgs/imgs/9652.png
#   inflating: imgs/imgs/9653.png
#   inflating: imgs/imgs/9654.png
#   inflating: imgs/imgs/9655.png
#   inflating: imgs/imgs/9656.png
#   inflating: imgs/imgs/9657.png
#   inflating: imgs/imgs/9658.png
#   inflating: imgs/imgs/9659.png
#   inflating: imgs/imgs/966.png
#   inflating: imgs/imgs/9660.png
#   inflating: imgs/imgs/9661.png
#   inflating: imgs/imgs/9662.png
#   inflating: imgs/imgs/9663.png
#   inflating: imgs/imgs/9664.png
#   inflating: imgs/imgs/9665.png
#   inflating: imgs/imgs/9666.png
#   inflating: imgs/imgs/9667.png
#   inflating: imgs/imgs/9668.png
#   inflating: imgs/imgs/9669.png
#   inflating: imgs/imgs/967.png
#   inflating: imgs/imgs/9670.png
#   inflating: imgs/imgs/9671.png
#   inflating: imgs/imgs/9672.png
#   inflating: imgs/imgs/9673.png
#   inflating: imgs/imgs/9674.png
#   inflating: imgs/imgs/9675.png
#   inflating: imgs/imgs/9676.png
#   inflating: imgs/imgs/9677.png
#   inflating: imgs/imgs/9678.png
#   inflating: imgs/imgs/9679.png
#   inflating: imgs/imgs/968.png
#   inflating: imgs/imgs/9680.png
#   inflating: imgs/imgs/9681.png
#   inflating: imgs/imgs/9682.png
#   inflating: imgs/imgs/9683.png
#   inflating: imgs/imgs/9684.png
#   inflating: imgs/imgs/9685.png
#   inflating: imgs/imgs/9686.png
#   inflating: imgs/imgs/9687.png
#   inflating: imgs/imgs/9688.png
#   inflating: imgs/imgs/9689.png
#   inflating: imgs/imgs/969.png
#   inflating: imgs/imgs/9690.png
#   inflating: imgs/imgs/9691.png
#   inflating: imgs/imgs/9692.png
#   inflating: imgs/imgs/9693.png
#   inflating: imgs/imgs/9694.png
#   inflating: imgs/imgs/9695.png
#   inflating: imgs/imgs/9696.png
#   inflating: imgs/imgs/9697.png
#   inflating: imgs/imgs/9698.png
#   inflating: imgs/imgs/9699.png
#   inflating: imgs/imgs/97.png
#   inflating: imgs/imgs/970.png
#   inflating: imgs/imgs/9700.png
#   inflating: imgs/imgs/9701.png
#   inflating: imgs/imgs/9702.png
#   inflating: imgs/imgs/9703.png
#   inflating: imgs/imgs/9704.png
#   inflating: imgs/imgs/9705.png
#   inflating: imgs/imgs/9706.png
#   inflating: imgs/imgs/9707.png
#   inflating: imgs/imgs/9708.png
#   inflating: imgs/imgs/9709.png
#   inflating: imgs/imgs/971.png
#   inflating: imgs/imgs/9710.png
#   inflating: imgs/imgs/9711.png
#   inflating: imgs/imgs/9712.png
#   inflating: imgs/imgs/9713.png
#   inflating: imgs/imgs/9714.png
#   inflating: imgs/imgs/9715.png
#   inflating: imgs/imgs/9716.png
#   inflating: imgs/imgs/9717.png
#   inflating: imgs/imgs/9718.png
#   inflating: imgs/imgs/9719.png
#   inflating: imgs/imgs/972.png
#   inflating: imgs/imgs/9720.png
#   inflating: imgs/imgs/9721.png
#   inflating: imgs/imgs/9722.png
#   inflating: imgs/imgs/9723.png
#   inflating: imgs/imgs/9724.png
#   inflating: imgs/imgs/9725.png
#   inflating: imgs/imgs/9726.png
#   inflating: imgs/imgs/9727.png
#   inflating: imgs/imgs/9728.png
#   inflating: imgs/imgs/9729.png
#   inflating: imgs/imgs/973.png
#   inflating: imgs/imgs/9730.png
#   inflating: imgs/imgs/9731.png
#   inflating: imgs/imgs/9732.png
#   inflating: imgs/imgs/9733.png
#   inflating: imgs/imgs/9734.png
#   inflating: imgs/imgs/9735.png
#   inflating: imgs/imgs/9736.png
#   inflating: imgs/imgs/9737.png
#   inflating: imgs/imgs/9738.png
#   inflating: imgs/imgs/9739.png
#   inflating: imgs/imgs/974.png
#   inflating: imgs/imgs/9740.png
#   inflating: imgs/imgs/9741.png
#   inflating: imgs/imgs/9742.png
#   inflating: imgs/imgs/9743.png
#   inflating: imgs/imgs/9744.png
#   inflating: imgs/imgs/9745.png
#   inflating: imgs/imgs/9746.png
#   inflating: imgs/imgs/9747.png
#   inflating: imgs/imgs/9748.png
#   inflating: imgs/imgs/9749.png
#   inflating: imgs/imgs/975.png
#   inflating: imgs/imgs/9750.png
#   inflating: imgs/imgs/9751.png
#   inflating: imgs/imgs/9752.png
#   inflating: imgs/imgs/9753.png
#   inflating: imgs/imgs/9754.png
#   inflating: imgs/imgs/9755.png
#   inflating: imgs/imgs/9756.png
#   inflating: imgs/imgs/9757.png
#   inflating: imgs/imgs/9758.png
#   inflating: imgs/imgs/9759.png
#   inflating: imgs/imgs/976.png
#   inflating: imgs/imgs/9760.png
#   inflating: imgs/imgs/9761.png
#   inflating: imgs/imgs/9762.png
#   inflating: imgs/imgs/9763.png
#   inflating: imgs/imgs/9764.png
#   inflating: imgs/imgs/9765.png
#   inflating: imgs/imgs/9766.png
#   inflating: imgs/imgs/9767.png
#   inflating: imgs/imgs/9768.png
#   inflating: imgs/imgs/9769.png
#   inflating: imgs/imgs/977.png
#   inflating: imgs/imgs/9770.png
#   inflating: imgs/imgs/9771.png
#   inflating: imgs/imgs/9772.png
#   inflating: imgs/imgs/9773.png
#   inflating: imgs/imgs/9774.png
#   inflating: imgs/imgs/9775.png
#   inflating: imgs/imgs/9776.png
#   inflating: imgs/imgs/9777.png
#   inflating: imgs/imgs/9778.png
#   inflating: imgs/imgs/9779.png
#   inflating: imgs/imgs/978.png
#   inflating: imgs/imgs/9780.png
#   inflating: imgs/imgs/9781.png
#   inflating: imgs/imgs/9782.png
#   inflating: imgs/imgs/9783.png
#   inflating: imgs/imgs/9784.png
#   inflating: imgs/imgs/9785.png
#   inflating: imgs/imgs/9786.png
#   inflating: imgs/imgs/9787.png
#   inflating: imgs/imgs/9788.png
#   inflating: imgs/imgs/9789.png
#   inflating: imgs/imgs/979.png
#   inflating: imgs/imgs/9790.png
#   inflating: imgs/imgs/9791.png
#   inflating: imgs/imgs/9792.png
#   inflating: imgs/imgs/9793.png
#   inflating: imgs/imgs/9794.png
#   inflating: imgs/imgs/9795.png
#   inflating: imgs/imgs/9796.png
#   inflating: imgs/imgs/9797.png
#   inflating: imgs/imgs/9798.png
#   inflating: imgs/imgs/9799.png
#   inflating: imgs/imgs/98.png
#   inflating: imgs/imgs/980.png
#   inflating: imgs/imgs/9800.png
#   inflating: imgs/imgs/9801.png
#   inflating: imgs/imgs/9802.png
#   inflating: imgs/imgs/9803.png
#   inflating: imgs/imgs/9804.png
#   inflating: imgs/imgs/9805.png
#   inflating: imgs/imgs/9806.png
#   inflating: imgs/imgs/9807.png
#   inflating: imgs/imgs/9808.png
#   inflating: imgs/imgs/9809.png
#   inflating: imgs/imgs/981.png
#   inflating: imgs/imgs/9810.png
#   inflating: imgs/imgs/9811.png
#   inflating: imgs/imgs/9812.png
#   inflating: imgs/imgs/9813.png
#   inflating: imgs/imgs/9814.png
#   inflating: imgs/imgs/9815.png
#   inflating: imgs/imgs/9816.png
#   inflating: imgs/imgs/9817.png
#   inflating: imgs/imgs/9818.png
#   inflating: imgs/imgs/9819.png
#   inflating: imgs/imgs/982.png
#   inflating: imgs/imgs/9820.png
#   inflating: imgs/imgs/9821.png
#   inflating: imgs/imgs/9822.png
#   inflating: imgs/imgs/9823.png
#   inflating: imgs/imgs/9824.png
#   inflating: imgs/imgs/9825.png
#   inflating: imgs/imgs/9826.png
#   inflating: imgs/imgs/9827.png
#   inflating: imgs/imgs/9828.png
#   inflating: imgs/imgs/9829.png
#   inflating: imgs/imgs/983.png
#   inflating: imgs/imgs/9830.png
#   inflating: imgs/imgs/9831.png
#   inflating: imgs/imgs/9832.png
#   inflating: imgs/imgs/9833.png
#   inflating: imgs/imgs/9834.png
#   inflating: imgs/imgs/9835.png
#   inflating: imgs/imgs/9836.png
#   inflating: imgs/imgs/9837.png
#   inflating: imgs/imgs/9838.png
#   inflating: imgs/imgs/9839.png
#   inflating: imgs/imgs/984.png
#   inflating: imgs/imgs/9840.png
#   inflating: imgs/imgs/9841.png
#   inflating: imgs/imgs/9842.png
#   inflating: imgs/imgs/9843.png
#   inflating: imgs/imgs/9844.png
#   inflating: imgs/imgs/9845.png
#   inflating: imgs/imgs/9846.png
#   inflating: imgs/imgs/9847.png
#   inflating: imgs/imgs/9848.png
#   inflating: imgs/imgs/9849.png
#   inflating: imgs/imgs/985.png
#   inflating: imgs/imgs/9850.png
#   inflating: imgs/imgs/9851.png
#   inflating: imgs/imgs/9852.png
#   inflating: imgs/imgs/9853.png
#   inflating: imgs/imgs/9854.png
#   inflating: imgs/imgs/9855.png
#   inflating: imgs/imgs/9856.png
#   inflating: imgs/imgs/9857.png
#   inflating: imgs/imgs/9858.png
#   inflating: imgs/imgs/9859.png
#   inflating: imgs/imgs/986.png
#   inflating: imgs/imgs/9860.png
#   inflating: imgs/imgs/9861.png
#   inflating: imgs/imgs/9862.png
#   inflating: imgs/imgs/9863.png
#   inflating: imgs/imgs/9864.png
#   inflating: imgs/imgs/9865.png
#   inflating: imgs/imgs/9866.png
#   inflating: imgs/imgs/9867.png
#   inflating: imgs/imgs/9868.png
#   inflating: imgs/imgs/9869.png
#   inflating: imgs/imgs/987.png
#   inflating: imgs/imgs/9870.png
#   inflating: imgs/imgs/9871.png
#   inflating: imgs/imgs/9872.png
#   inflating: imgs/imgs/9873.png
#   inflating: imgs/imgs/9874.png
#   inflating: imgs/imgs/9875.png
#   inflating: imgs/imgs/9876.png
#   inflating: imgs/imgs/9877.png
#   inflating: imgs/imgs/9878.png
#   inflating: imgs/imgs/9879.png
#   inflating: imgs/imgs/988.png
#   inflating: imgs/imgs/9880.png
#   inflating: imgs/imgs/9881.png
#   inflating: imgs/imgs/9882.png
#   inflating: imgs/imgs/9883.png
#   inflating: imgs/imgs/9884.png
#   inflating: imgs/imgs/9885.png
#   inflating: imgs/imgs/9886.png
#   inflating: imgs/imgs/9887.png
#   inflating: imgs/imgs/9888.png
#   inflating: imgs/imgs/9889.png
#   inflating: imgs/imgs/989.png
#   inflating: imgs/imgs/9890.png
#   inflating: imgs/imgs/9891.png
#   inflating: imgs/imgs/9892.png
#   inflating: imgs/imgs/9893.png
#   inflating: imgs/imgs/9894.png
#   inflating: imgs/imgs/9895.png
#   inflating: imgs/imgs/9896.png
#   inflating: imgs/imgs/9897.png
#   inflating: imgs/imgs/9898.png
#   inflating: imgs/imgs/9899.png
#   inflating: imgs/imgs/99.png
#   inflating: imgs/imgs/990.png
#   inflating: imgs/imgs/9900.png
#   inflating: imgs/imgs/9901.png
#   inflating: imgs/imgs/9902.png
#   inflating: imgs/imgs/9903.png
#   inflating: imgs/imgs/9904.png
#   inflating: imgs/imgs/9905.png
#   inflating: imgs/imgs/9906.png
#   inflating: imgs/imgs/9907.png
#   inflating: imgs/imgs/9908.png
#   inflating: imgs/imgs/9909.png
#   inflating: imgs/imgs/991.png
#   inflating: imgs/imgs/9910.png
#   inflating: imgs/imgs/9911.png
#   inflating: imgs/imgs/9912.png
#   inflating: imgs/imgs/9913.png
#   inflating: imgs/imgs/9914.png
#   inflating: imgs/imgs/9915.png
#   inflating: imgs/imgs/9916.png
#   inflating: imgs/imgs/9917.png
#   inflating: imgs/imgs/9918.png
#   inflating: imgs/imgs/9919.png
#   inflating: imgs/imgs/992.png
#   inflating: imgs/imgs/9920.png
#   inflating: imgs/imgs/9921.png
#   inflating: imgs/imgs/9922.png
#   inflating: imgs/imgs/9923.png
#   inflating: imgs/imgs/9924.png
#   inflating: imgs/imgs/9925.png
#   inflating: imgs/imgs/9926.png
#   inflating: imgs/imgs/9927.png
#   inflating: imgs/imgs/9928.png
#   inflating: imgs/imgs/9929.png
#   inflating: imgs/imgs/993.png
#   inflating: imgs/imgs/9930.png
#   inflating: imgs/imgs/9931.png
#   inflating: imgs/imgs/9932.png
#   inflating: imgs/imgs/9933.png
#   inflating: imgs/imgs/9934.png
#   inflating: imgs/imgs/9935.png
#   inflating: imgs/imgs/9936.png
#   inflating: imgs/imgs/9937.png
#   inflating: imgs/imgs/9938.png
#   inflating: imgs/imgs/9939.png
#   inflating: imgs/imgs/994.png
#   inflating: imgs/imgs/9940.png
#   inflating: imgs/imgs/9941.png
#   inflating: imgs/imgs/9942.png
#   inflating: imgs/imgs/9943.png
#   inflating: imgs/imgs/9944.png
#   inflating: imgs/imgs/9945.png
#   inflating: imgs/imgs/9946.png
#   inflating: imgs/imgs/9947.png
#   inflating: imgs/imgs/9948.png
#   inflating: imgs/imgs/9949.png
#   inflating: imgs/imgs/995.png
#   inflating: imgs/imgs/9950.png
#   inflating: imgs/imgs/9951.png
#   inflating: imgs/imgs/9952.png
#   inflating: imgs/imgs/9953.png
#   inflating: imgs/imgs/9954.png
#   inflating: imgs/imgs/9955.png
#   inflating: imgs/imgs/9956.png
#   inflating: imgs/imgs/9957.png
#   inflating: imgs/imgs/9958.png
#   inflating: imgs/imgs/9959.png
#   inflating: imgs/imgs/996.png
#   inflating: imgs/imgs/9960.png
#   inflating: imgs/imgs/9961.png
#   inflating: imgs/imgs/9962.png
#   inflating: imgs/imgs/9963.png
#   inflating: imgs/imgs/9964.png
#   inflating: imgs/imgs/9965.png
#   inflating: imgs/imgs/9966.png
#   inflating: imgs/imgs/9967.png
#   inflating: imgs/imgs/9968.png
#   inflating: imgs/imgs/9969.png
#   inflating: imgs/imgs/997.png
#   inflating: imgs/imgs/9970.png
#   inflating: imgs/imgs/9971.png
#   inflating: imgs/imgs/9972.png
#   inflating: imgs/imgs/9973.png
#   inflating: imgs/imgs/9974.png
#   inflating: imgs/imgs/9975.png
#   inflating: imgs/imgs/9976.png
#   inflating: imgs/imgs/9977.png
#   inflating: imgs/imgs/9978.png
#   inflating: imgs/imgs/9979.png
#   inflating: imgs/imgs/998.png
#   inflating: imgs/imgs/9980.png
#   inflating: imgs/imgs/9981.png
#   inflating: imgs/imgs/9982.png
#   inflating: imgs/imgs/9983.png
#   inflating: imgs/imgs/9984.png
#   inflating: imgs/imgs/9985.png
#   inflating: imgs/imgs/9986.png
#   inflating: imgs/imgs/9987.png
#   inflating: imgs/imgs/9988.png
#   inflating: imgs/imgs/9989.png
#   inflating: imgs/imgs/999.png
#   inflating: imgs/imgs/9990.png
#   inflating: imgs/imgs/9991.png
#   inflating: imgs/imgs/9992.png
#   inflating: imgs/imgs/9993.png
#   inflating: imgs/imgs/9994.png
#   inflating: imgs/imgs/9995.png
#   inflating: imgs/imgs/9996.png
#   inflating: imgs/imgs/9997.png
#   inflating: imgs/imgs/9998.png
#   inflating: imgs/imgs/9999.png
#   inflating: txn_history-2021-10-07.jsonl

# %%
data_dir = '/content/txn_history-2021-10-07.jsonl'
image_dir = "/content/imgs/imgs"
image_root = "/content/imgs"

# %%
df = pd.read_json('/content/txn_history-2021-10-07.jsonl', lines=True)
df.head()
# Out:
#         txn_type      from to       date  timestamp     source    eth  \
# 0  Bid Withdrawn  0xe73a1d    2021-09-04 2021-09-04  larvalabs  321.0
# 1            Bid  0xe73a1d    2021-09-01 2021-09-01  larvalabs  321.0
# 2  Bid Withdrawn  0x2e5e22    2021-09-01 2021-09-01  larvalabs  320.0
# 3            Bid  0x2e5e22    2021-09-01 2021-09-01  larvalabs  320.0
# 4  Bid Withdrawn  0x2e5e22    2021-09-01 2021-09-01  larvalabs  263.0
#
#    punk_id from_wallet_address to_wallet_address      type  \
# 0        0                None              None  [Female]
# 1        0                None              None  [Female]
# 2        0                None              None  [Female]
# 3        0                None              None  [Female]
# 4        0                None              None  [Female]
#
#                                accessories
# 0  [Green Eye Shadow, Earring, Blonde Bob]
# 1  [Green Eye Shadow, Earring, Blonde Bob]
# 2  [Green Eye Shadow, Earring, Blonde Bob]
# 3  [Green Eye Shadow, Earring, Blonde Bob]
# 4  [Green Eye Shadow, Earring, Blonde Bob]

# %%
#look at 100 samples

#define number of rows and cols
no_plots = 10*10

#define path
images = glob.glob("/content/imgs/imgs/*.png")

plt.rcParams['figure.figsize'] = (30, 30)
plt.subplots_adjust(wspace=0, hspace=0)

print("Sample 100 CryptoPunks")
for idx,image in enumerate(images[:no_plots]):
    sample_img = cv.imread(image)
    plt.subplot(10, 10, idx+1)
    plt.axis('off')
    plt.imshow(cv.cvtColor(sample_img,cv.COLOR_BGR2RGB)) #covert color space
plt.show()
# Out:
# Sample 100 CryptoPunks

# %%
punks = [img for img in glob.glob("/content/imgs/imgs/*.png")]

for punk in punks[0:3]:
    img = plt.imread(punk)
    plt.imshow(img)
    plt.show()

# %%
#check data summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167492 entries, 0 to 167491
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   txn_type             167492 non-null  object
#  1   from                 167492 non-null  object
#  2   to                   167492 non-null  object
#  3   date                 167492 non-null  datetime64[ns]
#  4   timestamp            167492 non-null  datetime64[ns]
#  5   source               167492 non-null  object
#  6   eth                  127542 non-null  float64
#  7   punk_id              167492 non-null  int64
#  8   from_wallet_address  419 non-null     object
#  9   to_wallet_address    419 non-null     object
#  10  type                 167492 non-null  object
#  11  accessories          167492 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(8)
# memory usage: 15.3+ MB

# %%
#create new dataframe with only useful columns
df = df[["txn_type", "date", "eth", "punk_id", "type", "accessories"]]
df.head()
# Out:
#         txn_type       date    eth  punk_id      type  \
# 0  Bid Withdrawn 2021-09-04  321.0        0  [Female]
# 1            Bid 2021-09-01  321.0        0  [Female]
# 2  Bid Withdrawn 2021-09-01  320.0        0  [Female]
# 3            Bid 2021-09-01  320.0        0  [Female]
# 4  Bid Withdrawn 2021-09-01  263.0        0  [Female]
#
#                                accessories
# 0  [Green Eye Shadow, Earring, Blonde Bob]
# 1  [Green Eye Shadow, Earring, Blonde Bob]
# 2  [Green Eye Shadow, Earring, Blonde Bob]
# 3  [Green Eye Shadow, Earring, Blonde Bob]
# 4  [Green Eye Shadow, Earring, Blonde Bob]

# %%
#value counts
df['txn_type'].unique()
# Out:
# array(['Bid Withdrawn', 'Bid', 'Sold', 'Offered', 'Transfer', 'Claimed',
#        'Offer Withdrawn', '(Wrap)', '(Unwrap)'], dtype=object)

# %%
df['accessories'].explode().unique()
# Out:
# array(['Green Eye Shadow', 'Earring', 'Blonde Bob', 'Smile', 'Mohawk',
#        'Wild Hair', 'Nerd Glasses', 'Pipe', 'Big Shades', 'Goat',
#        'Purple Eye Shadow', 'Half Shaved', 'Do-rag', 'Wild White Hair',
#        'Spots', 'Clown Eyes Blue', 'Messy Hair', 'Luxurious Beard',
#        'Clown Nose', 'Police Cap', 'Big Beard', 'Blue Eye Shadow',
#        'Black Lipstick', 'Clown Eyes Green', 'Straight Hair Dark',
#        'Blonde Short', 'Purple Lipstick', 'Straight Hair Blonde',
#        'Pilot Helmet', 'Hot Lipstick', 'Regular Shades', 'Stringy Hair',
#        'Small Shades', 'Frown', 'Eye Mask', 'Muttonchops', 'Bandana',
#        'Horned Rim Glasses', 'Crazy Hair', 'Classic Shades', 'Handlebars',
#        'Mohawk Dark', 'Dark Hair', 'Peak Spike', 'Normal Beard Black',
#        'Cap', 'VR', 'Frumpy Hair', 'Cigarette', 'Normal Beard',
#        'Red Mohawk', 'Shaved Head', 'Chinstrap', 'Mole', 'Knitted Cap',
#        'Fedora', 'Shadow Beard', 'Straight Hair', 'Hoodie', 'Eye Patch',
#        'Headband', 'Cowboy Hat', 'Tassle Hat', '3D Glasses', 'Mustache',
#        'Vape', 'Choker', 'Pink With Hat', 'Welding Goggles',
#        'Vampire Hair', 'Mohawk Thin', 'Tiara', 'Front Beard Dark',
#        'Cap Forward', 'Gold Chain', 'Purple Hair', 'Beanie',
#        'Clown Hair Green', 'Pigtails', 'Silver Chain', 'Front Beard',
#        'Rosy Cheeks', 'Orange Side', 'Wild Blonde', 'Buck Teeth', nan,
#        'Top Hat', 'Medical Mask'], dtype=object)

# %%
len(df['accessories'].explode().unique())
# Out:
# 88

# %%
#exploded 'type' list to rows of the subset columns
df = df.explode("type")
df.head()
# Out:
#         txn_type       date    eth  punk_id    type  \
# 0  Bid Withdrawn 2021-09-04  321.0        0  Female
# 1            Bid 2021-09-01  321.0        0  Female
# 2  Bid Withdrawn 2021-09-01  320.0        0  Female
# 3            Bid 2021-09-01  320.0        0  Female
# 4  Bid Withdrawn 2021-09-01  263.0        0  Female
#
#                                accessories
# 0  [Green Eye Shadow, Earring, Blonde Bob]
# 1  [Green Eye Shadow, Earring, Blonde Bob]
# 2  [Green Eye Shadow, Earring, Blonde Bob]
# 3  [Green Eye Shadow, Earring, Blonde Bob]
# 4  [Green Eye Shadow, Earring, Blonde Bob]

# %%
#visualize
fig = px.bar(df[df.txn_type == 'Sold'].groupby("type").agg({"eth": "max"}).sort_values(by="eth").reset_index('type'),
             x="type", 
             y="eth", 
             color="type", 
             title="CryptoPunk Types vs. Price")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7fcd9831-dda8-4177-8935-e680e844cda7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fcd9831-dda8-4177-8935-e680e844cda7")) {                    Plotly.newPlot(                        "7fcd9831-dda8-4177-8935-e680e844cda7",                        [{"alignmentgroup":"True","hovertemplate":"type=%{x}<br>eth=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"textposition":"auto","x":["Male"],"xaxis":"x","y":[667.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=%{x}<br>eth=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"textposition":"auto","x":["Female"],"xaxis":"x","y":[888.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=%{x}<br>eth=%{y}<extra></extra>","legendgroup":"Zombie","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Zombie","offsetgroup":"Zombie","orientation":"v","showlegend":true,"textposition":"auto","x":["Zombie"],"xaxis":"x","y":[2000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=%{x}<br>eth=%{y}<extra></extra>","legendgroup":"Ape","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Ape","offsetgroup":"Ape","orientation":"v","showlegend":true,"textposition":"auto","x":["Ape"],"xaxis":"x","y":[2250.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=%{x}<br>eth=%{y}<extra></extra>","legendgroup":"Alien","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Alien","offsetgroup":"Alien","orientation":"v","showlegend":true,"textposition":"auto","x":["Alien"],"xaxis":"x","y":[4200.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"] ...

# %%
#visualize human
human = df[(df.txn_type == 'Sold') & ((df.type == "Female") | (df.type == "Male")) ].groupby("date").agg({"eth": ["median"]}).reset_index("date")

#visualize alien
alien = df[(df.txn_type == 'Sold') & ((df.type == "Alien")) ].groupby("date").agg({"eth": ["median"]}).reset_index("date")

#visualize zombie
zombie = df[(df.txn_type == 'Sold') & ((df.type == "Zombie")) ].groupby("date").agg({"eth": ["median"]}).reset_index("date")

#visualize ape
ape = df[(df.txn_type == 'Sold') & ((df.type == "Ape")) ].groupby("date").agg({"eth": ["median"]}).reset_index("date")

plt.figure(figsize=(20,10))
plt.plot(human['date'], 
         human['eth']['median'], 
         label="Human Median Eth")

plt.plot(alien['date'], 
         alien['eth']['median'], 
         label="Alien Median Eth")

plt.plot(zombie['date'], 
         zombie['eth']['median'], 
         label="Zombie Median Eth")

plt.plot(ape['date'], 
         ape['eth']['median'], 
         label="Ape Median Eth")

plt.legend()
plt.xticks(rotation=60)
plt.title("Median Eth Price for Punks Sold Over Time by Type")
plt.show()

# %%
#get number of attributes
df['num_attributes'] = df.accessories.apply(lambda x: len(x))

# %%
#compare number of attributes vs. price
fig = px.bar(df[(df.txn_type == "Sold") & ((df.type == "Female") | (df.type == "Male"))].groupby("num_attributes").agg({"eth": "mean"}).reset_index("num_attributes"),
             x="num_attributes", 
             y="eth", 
             color="eth", 
             title="CryptoPunk Price per Number of Attributes of Human Punks")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2a9a6294-e1db-4784-bdd5-68d0efff961e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a9a6294-e1db-4784-bdd5-68d0efff961e")) {                    Plotly.newPlot(                        "2a9a6294-e1db-4784-bdd5-68d0efff961e",                        [{"alignmentgroup":"True","hovertemplate":"num_attributes=%{x}<br>eth=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[81.50272727272727,34.96868995633188,28.307821344339622,26.3428719261155,27.34807389937107,45.485875486381325,104.45875,37.63333333333333],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[0,1,2,3,4,5,6,7],"xaxis":"x","y":[81.50272727272727,34.96868995633188,28.307821344339622,26.3428719261155,27.34807389937107,45.485875486381325,104.45875,37.63333333333333],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tick ...

# %%
#visualize number of attributes vs price for alien
fig = px.bar(df[(df.txn_type == "Sold") & ((df.type == "Alien"))].groupby("num_attributes").agg({"eth": "mean"}).reset_index("num_attributes"),
             x="num_attributes", 
             y="eth", 
             color="eth", 
             title="CryptoPunk Price per Number of Attributes of Alien Punks")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4e25c6ba-37d7-4842-93a2-94dda61d1713" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e25c6ba-37d7-4842-93a2-94dda61d1713")) {                    Plotly.newPlot(                        "4e25c6ba-37d7-4842-93a2-94dda61d1713",                        [{"alignmentgroup":"True","hovertemplate":"num_attributes=%{x}<br>eth=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[965.8,10.0,1406.6666666666667],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3],"xaxis":"x","y":[965.8,10.0,1406.6666666666667],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...

# %%
#visualize number of attributes vs price for zombie
fig = px.bar(df[(df.txn_type == "Sold") & ((df.type == "Zombie"))].groupby("num_attributes").agg({"eth": "mean"}).reset_index("num_attributes"),
             x="num_attributes", 
             y="eth", 
             color="eth", 
             title="CryptoPunk Price per Number of Attributes of Zombie Punks")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e72c8f4a-aa39-4bce-942d-611765cf1c8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e72c8f4a-aa39-4bce-942d-611765cf1c8b")) {                    Plotly.newPlot(                        "e72c8f4a-aa39-4bce-942d-611765cf1c8b",                        [{"alignmentgroup":"True","hovertemplate":"num_attributes=%{x}<br>eth=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[210.60700000000003,222.70574468085107,188.71512195121952,68.79857142857142],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3,4],"xaxis":"x","y":[210.60700000000003,222.70574468085107,188.71512195121952,68.79857142857142],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":t ...

# %%
#visualize number of attributes vs price for ape
fig = px.bar(df[(df.txn_type == "Sold") & ((df.type == "Ape"))].groupby("num_attributes").agg({"eth": "mean"}).reset_index("num_attributes"),
             x="num_attributes", 
             y="eth", 
             color="eth", 
             title="CryptoPunk Price per Number of Attributes of Ape Punks")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="076e3b02-162e-4818-aa39-06e983d0a23b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("076e3b02-162e-4818-aa39-06e983d0a23b")) {                    Plotly.newPlot(                        "076e3b02-162e-4818-aa39-06e983d0a23b",                        [{"alignmentgroup":"True","hovertemplate":"num_attributes=%{x}<br>eth=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[121.16000000000001,331.95875,2.6],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1,2,3],"xaxis":"x","y":[121.16000000000001,331.95875,2.6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"ty ...

# %% [markdown]
# # DC-GAN Intuition
#
# * generator generates data for discriminator training using latent embedding (usually random noise)
# * discriminator distinguishes the generator's generated data from real data and penalizes the generator for fake data.
# * The two networks are set out to compete with each other i.e. "adversarial". Overtime, the generator gets better at generating images that are super close to real images and discriminator gets better at differentiating them.
#
# The generator network takes random Gaussian noise and maps it into input images such that the discriminator cannot tell which images came from the dataset and which images came from the generator. The discriminator will be trained to learn to tell the difference between images comes from the dataset and images comes from the generator.
#
# GANs typically work with image data and use Convolutional Neural Networks, (CNNs). A CNN architecture is composed of convolutional layer with ReLU, pooling layer, and lastly fully connected Dense layers.

# %% [markdown]
# # DataLoader & Preprocessing

# %%
#display tensor image
def tensor_imshow(img, dnorm=True):
    img = img.to('cpu')
    npimg = img.detach().numpy()
    if dnorm:
        npimg = npimg*0.5+0.5
    plt.figure(figsize=(3, 3))
    plt.axis('off')
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
def get_dataloader(batch_size,           #batch size during training
                   image_size,           #spatial size of training images
                   data_dir=image_dir,   #root directory for dataset
                   num_workers=3):       #number of sub-processes
    
    stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5) 
    
    #create transformer to transform images
    transform = transforms.Compose([transforms.Resize((image_size, image_size)),  #resize
                                    transforms.ToTensor(),                        #convert to tensor
                                    transforms.Normalize(*stats)])                #normalize to be between -1 and 1
    
    #create the dataset
    dataset = datasets.ImageFolder(root=data_dir,
                                   transform=transform)
    
    #create the dataloader
    data_loader = torch.utils.data.DataLoader(dataset,
                                              batch_size=batch_size,
                                              shuffle=True,
                                              num_workers=num_workers,
                                              pin_memory=True)
    
    return data_loader

# %%
#test dataloader
batch_size, image_size = 5, 24

train_loader = get_dataloader(batch_size,
                              image_size,
                              image_root)

dataiter = iter(train_loader) #dataloader is an iterator

img,_ = next(dataiter)
sample_img = img[-1]

#display tensor image
tensor_imshow(sample_img)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning:
#
# This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.

# %% [markdown]
# # Build Generator
#
# During generator training:
#
# * The generator takes in a random input and output a single 64x64 colored image.
# * The image is upsampled: doubling in size and quadrupling in the area of activations each time it passes through the ConvTranspose2d layer.
#
# As the result, the generator learns how to map the low dimensional image to the high dimensional image more and more effectively to fool the discriminator.

# %%
class Generator(nn.Module):       #signals neural network
    def __init__(self, 
                 z_dim=100,      #noise vector
                 im_chan=3,      #color chanel, 3 for red green blue
                 hidden_dim=64): #spatial size of feature map (conv)
        
        super(Generator, self).__init__()
        self.z_dim = z_dim
        self.im_chan = im_chan
        self.hidden_dim = hidden_dim
        
        self.generator_cnn = nn.Sequential(self.make_gen_block(z_dim, hidden_dim*8, stride=1, padding=0),   
                                           #(64*8) x 4 x 4
                                           self.make_gen_block(hidden_dim*8, hidden_dim*4),                           
                                           #(64*4) x 8 x 8
                                           self.make_gen_block(hidden_dim*4, hidden_dim*2),                           
                                           #(64*2) x 16 x 16
                                           self.make_gen_block(hidden_dim*2, hidden_dim),                             
                                           #(64) x 32 x 32
                                           self.make_gen_block(hidden_dim, im_chan, final_layer=True))
    
    def make_gen_block(self, 
                       im_chan,     #image dimension
                       op_chan,     #output dimension
                       kernel_size=4, 
                       stride=2, 
                       padding=1, 
                       final_layer=False): 
        
        layers = []
        #de-convolutional layer
        layers.append(nn.ConvTranspose2d(im_chan,     
                                         op_chan, 
                                         kernel_size, 
                                         stride, 
                                         padding, 
                                         bias=False))
        
        if not final_layer:
            layers.append(nn.BatchNorm2d(op_chan))
            layers.append(nn.LeakyReLU(0.2))
        else:
            layers.append(nn.Tanh())
        
        return nn.Sequential(*layers)
    
    def forward(self,noise):
        x = noise.view(-1,self.z_dim,1,1)
        return self.generator_cnn(x)

    def get_noise(n_samples, 
                  z_dim, 
                  device='cpu'):
        return torch.randn(n_samples, 
                           z_dim, 
                           device=device)

# %%
#test Generator
noise = Generator.get_noise(n_samples=5,
                            z_dim=100)

g = Generator(z_dim=100,
              im_chan=3,
              hidden_dim=64)

# %%
print(g)
# Out:
# Generator(
#   (generator_cnn): Sequential(
#     (0): Sequential(
#       (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (1): Sequential(
#       (0): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (2): Sequential(
#       (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): Tanh()
#     )
#   )
# )

# %% [markdown]
# # Build Discriminator
#
# The discriminator's training data comes from two sources:
#
# * real data: The discriminator uses these instances as positive examples during training. This is classified as 0.
# * fake data created by the generator: The discriminator uses these instances as negative examples during training. This is classified as 1.
#
# During discriminator training:
#
# * The discriminator takes in one input image and outputs a binary prediction to classify when the image is real or fake.
# * The discriminator_loss penalizes itself if it misclassifies the image. The total loss is the sum of the losses for real and fake images, discriminator_loss = real_loss + fake_loss.
# * The discriminator updates its weights through back-propagation from the discriminator loss through the discriminator network.

# %%
class Discriminator(nn.Module):
    def __init__(self, 
                 im_chan=3,       #image channels, 3 for red green blue
                 conv_dim=64,     #spatial dimension of feature map
                 image_size=64):  #spatial size of training images
        
        super(Discriminator, self).__init__()
        self.image_size = image_size
        self.conv_dim = conv_dim
        
        self.disc_cnn = nn.Sequential(self.make_disc_block(im_chan, conv_dim),
                                      self.make_disc_block(conv_dim, conv_dim*2),
                                      self.make_disc_block(conv_dim*2, conv_dim*4),
                                      self.make_disc_block(conv_dim*4, conv_dim*8),
                                      #no need a sigmoid here since it is included in the loss function
                                      self.make_disc_block(conv_dim*8, 1, padding=0, final_layer=True)) 
        
        
    def make_disc_block(self,
                        im_chan,
                        op_chan,
                        kernel_size=4,
                        stride=2,
                        padding=1,
                        final_layer=False):
        layers = []
        layers.append(nn.Conv2d(im_chan,
                                op_chan,
                                kernel_size,
                                stride,
                                padding,
                                bias=False))
        
        if not final_layer:
            layers.append(nn.BatchNorm2d(op_chan))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
        
        return nn.Sequential(*layers)
    
    #given an image tensor, returns a 1-dimension tensor representing fake/real
    def forward(self,image):
        pred = self.disc_cnn(image)
        pred = pred.view(image.size(0),-1)
        return pred
    
    def _get_final_feature_dimention(self):
        final_width_height = (self.image_size //  2**len(self.disc_cnn))**2
        final_depth = self.conv_dim * 2**(len(self.disc_cnn)-1)
        return final_depth*final_width_height

# %%
#test Discriminator
d = Discriminator(im_chan=3,
                  conv_dim=64,
                  image_size=64)

# %%
print(d)
# Out:
# Discriminator(
#   (disc_cnn): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2), bias=False)
#     )
#   )
# )

# %% [markdown]
# # Define Training Parameters

# %% [markdown]
# ## Weight Initialization
#
# All model weights will be randomly initialized from a normal distribution with mean=0, stdev=0.2 according to Goodfellow (2014).
#
# * weights_init_normal: takes an initialized model as input and reinitializes all convolutional, convolutional-transpose, and batch normalization layers to meet this criteria. This function is applied to the models immediately after initialization.

# %%
#custom weights initialization to randomly initialize all weights
#mean=0, stdev=0.2
def weights_init_normal(m):
    
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.ConvTranspose2d):
        torch.nn.init.normal_(m.weight, 0.0, 0.02) 
        
    if isinstance(m, nn.BatchNorm2d):
        torch.nn.init.normal_(m.weight, 0.0, 0.02)
        torch.nn.init.constant_(m.bias, 0)

# %% [markdown]
# ## Loss Functions
#
# Now we create loss functions to calculate the discriminator's loss and the generator's loss. This is how the discriminator and generator will know how they are doing and improve themselves.

# %%
def real_loss(D_out,device='cpu'):
    
    #initialize BCELoss function
    criterion = nn.BCEWithLogitsLoss()
    
    #batch size
    batch_size = D_out.size(0)
    
    #labels will be used when calculating the losses
    #real labels = 1 and lable smoothing => 0.9
    labels = torch.ones(batch_size, device=device)*0.9 
    
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
def fake_loss(D_out, device='cpu'):
    
    #initialize BCELoss function
    criterion = nn.BCEWithLogitsLoss()
    
    #batch size
    batch_size = D_out.size(0)
    
    #labels will be used when calculating the losses
    #fake labels = 0
    labels = torch.zeros(batch_size,
                         device=device) 
    
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# # Training Procedure
#
# **Part 1 - Train the discriminator**
#
# * Generate fixed_z to get a fixed batch of latent vectors which we will use to keep track of the generator learning progression.
# * Train the discriminator with all-real batches of images: forward pass, calculate d_real_loss with real_loss() and calculate the gradients in a backward pass gradients in a backward pass with backward().
# * Use the generator to generate all-fake batches of images and use that to train the discriminator: forward pass, calculate d_fake_loss with fake_loss() and and calculate the gradients in a backward pass with backward()
# * Total d_loss with be the sum of d_real_loss and d_fake_loss.
# * Update d_optimizer with step().
#
# **Part 2 - Train the generator**
#
# * Use discriminator to classify generator's output g_out.
# * Computes generator's loss using real_loss().
# * Computes generator's gradients in a backward pass with backward().
# * Updates generator's optimizer with step().
#
# For every mini-batch of data, we train the discriminator for one iteration, and then the generator for one iteration.

# %%
def print_tensor_images(images_tensor):
    
    '''
    Function for visualizing images: Given a tensor of images, prints the images.
    '''
        
    plt.rcParams['figure.figsize'] = (15, 15)
    plt.subplots_adjust(wspace=0, hspace=0)
    
    images_tensor = images_tensor.to('cpu')
    npimgs = images_tensor.detach().numpy()
    
    no_plots = len(images_tensor)

    for idx,image in enumerate(npimgs):
        plt.subplot(1, 8, idx+1)
        plt.axis('off')
        #dnorm
        image = image * 0.5 + 0.5
        plt.imshow(np.transpose(image, (1, 2, 0)))
        
    plt.show()

# %%
def train(D, G, 
          n_epochs,
          dataloader,
          d_optimizer,
          g_optimizer,
          z_dim,
          print_every=50,
          device='cpu'):
    
    #to keep track of the generator’s learning progression, 
    #we will generate a fixed batch of latent vectors that are drawn from a Gaussian distribution   
    sample_size=8
    fixed_z = Generator.get_noise(n_samples=sample_size,
                                  z_dim=z_dim,
                                  device=device)
    
    for epoch in range(1,n_epochs+1):
        #use dataloader to fetch batches
        for batch_i,(real_images,_) in enumerate(dataloader):
            batch_size = real_images.size(0)
            real_images = real_images.to(device)
            
            #Part 1: Train the Discriminator ========================================================
            #goal: to maximize the probability of correctly classifying a given input as real or fake
            
            #zero out the gradients before backpropagation
            d_optimizer.zero_grad()
            
            ##classify all-real batch
            d_real_op = D(real_images) #average output (across the batch) of the discriminator
            d_real_loss = real_loss(d_real_op,
                                    device=device)
            
            #train with all-fake batch
            noise = Generator.get_noise(n_samples=batch_size,
                                        z_dim=z_dim,
                                        device=device)
            fake_images = G(noise)
            
            #classify all-fake batch
            d_fake_op = D(fake_images) #average output (across the batch) of the generator
            d_fake_loss = fake_loss(d_fake_op,
                                    device=device)
            
            #total loss
            d_loss = d_real_loss + d_fake_loss
            
            #update gradients
            d_loss.backward()
            #update optimizer
            d_optimizer.step()
            
            #Part 2: Train the Generator ==============================================================
            #zero out the gradients before backpropagation
            g_optimizer.zero_grad()
            noise = Generator.get_noise(n_samples=batch_size,
                                        z_dim=z_dim,
                                        device=device)
            
            #use discriminator to classify generator's output
            g_out = G(noise)
            d_out = D(g_out)
            
            g_loss = real_loss(d_out, 
                               device=device) 
            #update gradients
            g_loss.backward()
            #update optimizer
            g_optimizer.step()
        
        print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(epoch, 
                                                                               n_epochs, 
                                                                               d_loss.item(),  #keep track of loss
                                                                               g_loss.item())) #keep track of loss
        if (epoch % print_every == 0):
            G.eval()
            sample_image = G(fixed_z)
            print_tensor_images(sample_image)
            G.train()

# %% [markdown]
# ## Train Time!

# %%
#hyperparameters
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device is ", device)

#incorrect hyperparameter settings lead to mode collapse
#we will follow Goodfellow’s paper
z_dim = 100       #noise
beta_1 = 0.5      #as specified in the original DCGAN paper
beta_2 = 0.999 
lr = 0.0002       #as specified in the original DCGAN paper
n_epochs = 100
batch_size = 128
image_size = 64
# Out:
# Device is  cpu

# %%
#initialize generator
generator = Generator(z_dim, 
                      im_chan=3, 
                      hidden_dim=64).to(device)

#initialize discriminator
discriminator = Discriminator(im_chan=3, 
                              conv_dim=64, 
                              image_size=image_size).to(device)

#setup Adam optimizers for generator
g_optimizer = optim.Adam(generator.parameters(), 
                         lr=lr, 
                         betas=(beta_1, beta_2))

#setup Adam optimizers for discriminator
d_optimizer = optim.Adam(discriminator.parameters(), 
                         lr=lr, 
                         betas=(beta_1, beta_2))

#setup dataloader
dataloader = get_dataloader(batch_size, 
                            image_size, 
                            image_root)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning:
#
# This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.

# %%
#start training
# %time
n_epochs = 100
train(discriminator,
      generator,
      n_epochs,
      dataloader,
      d_optimizer,
      g_optimizer,
      z_dim,
      print_every=10,
      device=device)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.39 µs
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning:
#
# This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.

# %%
plt.figure(figsize = (15, 8))
plt.plot(noise)
plt.title("Noise")
plt.show()

# %%
def save_model(generator,file_name):
    generator = generator.to('cuda')
    torch.save(generator.state_dict(),"cryptopunks_generator.pth")

save_model(generator,"kaggle")

# %% [markdown]
# # Create New CryptoPunks

# %%
#sample generation
generator.to(device)
generator.eval()       #eval mode
sample_size=8

for i in range(8):    
    
    #generate latent vectors
    fixed_z = Generator.get_noise(n_samples=sample_size, 
                                  z_dim=z_dim, 
                                  device=device)    
    
    #generate samples
    sample_image = generator(fixed_z)
    
    #display samples
    print_tensor_images(sample_image)
